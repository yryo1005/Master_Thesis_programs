# %%
from utils import *

# %%
with open("../../results/Neural_Joking_Machine/001/index_to_word.json", "r") as f:
    index_to_word = json.load(f)
index_to_word = {
    int(K):V for K, V in index_to_word.items()
}

njm = NeuralJokingMachine(weight_path = "../../results/Neural_Joking_Machine/001/best_model_weights.pth",
                          index_to_word = index_to_word,
                          sentence_length = 32,
                          embedding_dim = 2048)
# Out:
# /home/user/workspace/Master_Thesis/Master_Thesis_programs/Neural_Joking_Machine_v1/utils.py:234: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !wget https://d2dcan0armyq93.cloudfront.net/photo/odai/600/a7214653889c4a6755e4384f2401c126_600.jpg -O test_image.jpg
generated_boke = njm("test_image.jpg", argmax = False)

fig = plt.figure()
ax = fig.add_subplot()
ax.imshow(Image.open("test_image.jpg"))
ax.axis("off")
ax.set_title(f"大喜利: {generated_boke}")
# Out:
# --2024-12-17 11:48:43--  https://d2dcan0armyq93.cloudfront.net/photo/odai/600/a7214653889c4a6755e4384f2401c126_600.jpg
# Resolving d2dcan0armyq93.cloudfront.net (d2dcan0armyq93.cloudfront.net)... 13.249.166.109, 13.249.166.90, 13.249.166.231, ...
# Connecting to d2dcan0armyq93.cloudfront.net (d2dcan0armyq93.cloudfront.net)|13.249.166.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28143 (27K) [image/jpeg]
# Saving to: ‘test_image.jpg’
#
# test_image.jpg      100%[===================>]  27.48K  --.-KB/s    in 0s
#
# 2024-12-17 11:48:43 (149 MB/s) - ‘test_image.jpg’ saved [28143/28143]
# Text(0.5, 1.0, '大喜利: 自己管理能力の測定方法を雇ったが犬')

# %%
# !wget https://d2dcan0armyq93.cloudfront.net/photo/odai/600/75c100e506b8935ce69cbadb8eda8bd7_600.jpg -O test_image.jpg
generated_boke = njm("test_image.jpg", argmax = False)

fig = plt.figure()
ax = fig.add_subplot()
ax.imshow(Image.open("test_image.jpg"))
ax.axis("off")
ax.set_title(f"大喜利: {generated_boke}")
# Out:
# --2024-12-17 11:49:04--  https://d2dcan0armyq93.cloudfront.net/photo/odai/600/75c100e506b8935ce69cbadb8eda8bd7_600.jpg
# Resolving d2dcan0armyq93.cloudfront.net (d2dcan0armyq93.cloudfront.net)... 13.249.166.109, 13.249.166.90, 13.249.166.231, ...
# Connecting to d2dcan0armyq93.cloudfront.net (d2dcan0armyq93.cloudfront.net)|13.249.166.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40262 (39K) [image/jpeg]
# Saving to: ‘test_image.jpg’
#
# test_image.jpg      100%[===================>]  39.32K  --.-KB/s    in 0.003s
#
# 2024-12-17 11:49:04 (11.9 MB/s) - ‘test_image.jpg’ saved [40262/40262]
# Text(0.5, 1.0, '大喜利: お父さん・・・また電気止められてるわ')

# %%
# !wget https://d2dcan0armyq93.cloudfront.net/photo/odai/600/a7d1e26dc93ee0a4d3b16f80dd0954ea_600.jpg -O test_image.jpg
generated_boke = njm("test_image.jpg", argmax = False)

fig = plt.figure()
ax = fig.add_subplot()
ax.imshow(Image.open("test_image.jpg"))
ax.axis("off")
ax.set_title(f"大喜利: {generated_boke}")
# Out:
# --2024-12-17 11:49:27--  https://d2dcan0armyq93.cloudfront.net/photo/odai/600/a7d1e26dc93ee0a4d3b16f80dd0954ea_600.jpg
# Resolving d2dcan0armyq93.cloudfront.net (d2dcan0armyq93.cloudfront.net)... 13.249.166.109, 13.249.166.197, 13.249.166.90, ...
# Connecting to d2dcan0armyq93.cloudfront.net (d2dcan0armyq93.cloudfront.net)|13.249.166.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34341 (34K) [image/jpeg]
# Saving to: ‘test_image.jpg’
#
# test_image.jpg      100%[===================>]  33.54K  --.-KB/s    in 0.001s
#
# 2024-12-17 11:49:27 (59.3 MB/s) - ‘test_image.jpg’ saved [34341/34341]
# Text(0.5, 1.0, '大喜利: 「この人痴漢です」と言ったのにすぐあっさり捕まる')
