# %% [markdown]
# # Cross Attentionが3層

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: 64
# - LEARNING RATE: 0.0001
# - FEATURE DIM: 1024
# - NUM_HEAD: 8

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 64 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 8
# Out:
# 25
# 2025-01-06 23:14:54.642699: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-06 23:14:54.650845: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-06 23:14:54.653260: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-06 23:14:54.659265: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-06 23:14:55.119990: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# result directory: ../../results/GUMI_T_3/False_False_False_0_32_4_31_25_64_0.0001_1024_8/
# 100%|█████████████████████████████████| 668970/668970 [06:37<00:00, 1682.90it/s]
# 100%|█████████████████████████████| 2135982/2135982 [00:03<00:00, 662439.71it/s]
# 100%|█████████████████████████████| 2051435/2051435 [00:02<00:00, 837832.58it/s]
# 学習に用いる大喜利の数: 2030920
#  検証に用いる大喜利の数: 20515
#  使用する画像の数: 244286
#  単語の種類: 16705
# 100%|███████████████████████████████| 244286/244286 [00:01<00:00, 236772.49it/s]
# 100%|█████████████████████████████| 2030920/2030920 [00:06<00:00, 322595.12it/s]
# num data: 2030920
# 100%|█████████████████████████████████| 20515/20515 [00:00<00:00, 669364.57it/s]
# num data: 20515
# Epoch 1/25: 100%|█| 31734/31734 [1:22:04<00:00,  6.44it/s, train_loss=4.43, trai
# Evaluating: 100%|█| 321/321 [00:34<00:00,  9.18it/s, test_loss=4.07, test_accura
# Epoch: 1/25, Train Loss: 4.4277, Train Accuracy: 0.2854, Test Loss: 4.0563, Test Accuracy: 0.3156
# -------------------------
# Epoch 2/25: 100%|█| 31734/31734 [1:17:55<00:00,  6.79it/s, train_loss=3.89, trai
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.86it/s, test_loss=3.91, test_accura
# Epoch: 2/25, Train Loss: 3.8915, Train Accuracy: 0.3279, Test Loss: 3.9098, Test Accuracy: 0.3306
# -------------------------
# Epoch 3/25: 100%|█| 31734/31734 [1:12:32<00:00,  7.29it/s, train_loss=3.71, trai
# Evaluating: 100%|█| 321/321 [00:34<00:00,  9.24it/s, test_loss=3.85, test_accura
# Epoch: 3/25, Train Loss: 3.7099, Train Accuracy: 0.3444, Test Loss: 3.8524, Test Accuracy: 0.3378
# -------------------------
# Epoch 4/25: 100%|█| 31734/31734 [1:12:40<00:00,  7.28it/s, train_loss=3.59, trai
# Evaluating: 100%|█| 321/321 [00:34<00:00,  9.19it/s, test_loss=3.84, test_accura
# Epoch: 4/25, Train Loss: 3.5927, Train Accuracy: 0.3555, Test Loss: 3.8325, Test Accuracy: 0.3404
# -------------------------
# Epoch 5/25: 100%|█| 31734/31734 [1:12:34<00:00,  7.29it/s, train_loss=3.5, train
# Evaluating: 100%|█| 321/321 [00:34<00:00,  9.23it/s, test_loss=3.84, test_accura
# Epoch: 5/25, Train Loss: 3.5045, Train Accuracy: 0.3641, Test Loss: 3.8258, Test Accuracy: 0.3415
# -------------------------
# Epoch 6/25: 100%|█| 31734/31734 [1:12:40<00:00,  7.28it/s, train_loss=3.43, trai
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.85it/s, test_loss=3.84, test_accura
# Epoch: 6/25, Train Loss: 3.4337, Train Accuracy: 0.3711, Test Loss: 3.8290, Test Accuracy: 0.3424
# -------------------------
# Epoch 7/25: 100%|█| 31734/31734 [1:20:00<00:00,  6.61it/s, train_loss=3.37, trai
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.82it/s, test_loss=3.85, test_accura
# Epoch: 7/25, Train Loss: 3.3738, Train Accuracy: 0.3773, Test Loss: 3.8359, Test Accuracy: 0.3424
# -------------------------
# Epoch 8/25: 100%|█| 31734/31734 [1:12:47<00:00,  7.27it/s, train_loss=3.32, trai
# Evaluating: 100%|█| 321/321 [00:34<00:00,  9.20it/s, test_loss=3.84, test_accura
# Epoch: 8/25, Train Loss: 3.3223, Train Accuracy: 0.3827, Test Loss: 3.8446, Test Accuracy: 0.3426
# -------------------------
# Epoch 9/25: 100%|█| 31734/31734 [1:12:29<00:00,  7.30it/s, train_loss=3.28, trai
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.83it/s, test_loss=3.87, test_accura
# Epoch: 9/25, Train Loss: 3.2767, Train Accuracy: 0.3875, Test Loss: 3.8555, Test Accuracy: 0.3429
# -------------------------
# Epoch 10/25: 100%|█| 31734/31734 [1:18:04<00:00,  6.77it/s, train_loss=3.23, tra
# Evaluating: 100%|█| 321/321 [00:34<00:00,  9.23it/s, test_loss=3.88, test_accura
# Epoch: 10/25, Train Loss: 3.2347, Train Accuracy: 0.3921, Test Loss: 3.8700, Test Accuracy: 0.3428
# -------------------------
# Epoch 11/25: 100%|█| 31734/31734 [1:13:59<00:00,  7.15it/s, train_loss=3.2, trai
# Evaluating: 100%|█| 321/321 [00:34<00:00,  9.34it/s, test_loss=3.88, test_accura
# Epoch: 11/25, Train Loss: 3.1960, Train Accuracy: 0.3962, Test Loss: 3.8827, Test Accuracy: 0.3422
# -------------------------
# Epoch 12/25: 100%|█| 31734/31734 [1:22:01<00:00,  6.45it/s, train_loss=3.16, tra
# Evaluating: 100%|█| 321/321 [00:35<00:00,  9.16it/s, test_loss=3.91, test_accura
# Epoch: 12/25, Train Loss: 3.1609, Train Accuracy: 0.4002, Test Loss: 3.8935, Test Accuracy: 0.3416
# -------------------------
# Epoch 13/25: 100%|█| 31734/31734 [1:13:49<00:00,  7.16it/s, train_loss=3.13, tra
# Evaluating: 100%|█| 321/321 [00:34<00:00,  9.23it/s, test_loss=3.92, test_accura
# Epoch: 13/25, Train Loss: 3.1272, Train Accuracy: 0.4041, Test Loss: 3.9042, Test Accuracy: 0.3411
# -------------------------
# Epoch 14/25: 100%|█| 31734/31734 [1:19:07<00:00,  6.68it/s, train_loss=3.1, trai
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.74it/s, test_loss=3.93, test_accura
# Epoch: 14/25, Train Loss: 3.0957, Train Accuracy: 0.4077, Test Loss: 3.9196, Test Accuracy: 0.3403
# -------------------------
# Epoch 15/25: 100%|█| 31734/31734 [1:22:10<00:00,  6.44it/s, train_loss=3.06, tra
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.79it/s, test_loss=3.94, test_accura
# Epoch: 15/25, Train Loss: 3.0649, Train Accuracy: 0.4113, Test Loss: 3.9316, Test Accuracy: 0.3397
# -------------------------
# Epoch 16/25: 100%|█| 31734/31734 [1:12:49<00:00,  7.26it/s, train_loss=3.04, tra
# Evaluating: 100%|█| 321/321 [00:34<00:00,  9.21it/s, test_loss=3.96, test_accura
# Epoch: 16/25, Train Loss: 3.0356, Train Accuracy: 0.4148, Test Loss: 3.9499, Test Accuracy: 0.3390
# -------------------------
# Epoch 17/25: 100%|█| 31734/31734 [1:27:12<00:00,  6.07it/s, train_loss=3.01, tra
# Evaluating: 100%|█| 321/321 [00:34<00:00,  9.21it/s, test_loss=3.97, test_accura
# Epoch: 17/25, Train Loss: 3.0076, Train Accuracy: 0.4181, Test Loss: 3.9702, Test Accuracy: 0.3381
# -------------------------
# Epoch 18/25: 100%|█| 31734/31734 [1:14:07<00:00,  7.14it/s, train_loss=2.98, tra
# Evaluating: 100%|█| 321/321 [00:35<00:00,  9.16it/s, test_loss=3.98, test_accura
# Epoch: 18/25, Train Loss: 2.9806, Train Accuracy: 0.4215, Test Loss: 3.9843, Test Accuracy: 0.3381
# -------------------------
# Epoch 19/25: 100%|█| 31734/31734 [1:31:10<00:00,  5.80it/s, train_loss=2.95, tra
# Evaluating: 100%|█| 321/321 [00:37<00:00,  8.59it/s, test_loss=4, test_accuracy=
# Epoch: 19/25, Train Loss: 2.9535, Train Accuracy: 0.4248, Test Loss: 3.9986, Test Accuracy: 0.3367
# -------------------------
# Epoch 20/25: 100%|█| 31734/31734 [1:18:09<00:00,  6.77it/s, train_loss=2.93, tra
# Evaluating: 100%|█| 321/321 [00:35<00:00,  9.15it/s, test_loss=4.02, test_accura
# Epoch: 20/25, Train Loss: 2.9281, Train Accuracy: 0.4280, Test Loss: 4.0156, Test Accuracy: 0.3369
# -------------------------
# Epoch 21/25: 100%|█| 31734/31734 [1:18:47<00:00,  6.71it/s, train_loss=2.9, trai
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.77it/s, test_loss=4.05, test_accura
# Epoch: 21/25, Train Loss: 2.9023, Train Accuracy: 0.4313, Test Loss: 4.0342, Test Accuracy: 0.3362
# -------------------------
# Epoch 22/25: 100%|█| 31734/31734 [1:16:24<00:00,  6.92it/s, train_loss=2.88, tra
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.83it/s, test_loss=4.06, test_accura
# Epoch: 22/25, Train Loss: 2.8774, Train Accuracy: 0.4346, Test Loss: 4.0569, Test Accuracy: 0.3351
# -------------------------
# Epoch 23/25: 100%|█| 31734/31734 [1:14:01<00:00,  7.14it/s, train_loss=2.85, tra
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.75it/s, test_loss=4.08, test_accura
# Epoch: 23/25, Train Loss: 2.8531, Train Accuracy: 0.4378, Test Loss: 4.0768, Test Accuracy: 0.3335
# -------------------------
# Epoch 24/25: 100%|█| 31734/31734 [1:15:50<00:00,  6.97it/s, train_loss=2.83, tra
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.78it/s, test_loss=4.1, test_accurac
# Epoch: 24/25, Train Loss: 2.8303, Train Accuracy: 0.4408, Test Loss: 4.0885, Test Accuracy: 0.3336
# -------------------------
# Epoch 25/25: 100%|█| 31734/31734 [1:21:38<00:00,  6.48it/s, train_loss=2.81, tra
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.79it/s, test_loss=4.12, test_accura
# Epoch: 25/25, Train Loss: 2.8072, Train Accuracy: 0.4439, Test Loss: 4.1119, Test Accuracy: 0.3321
# -------------------------

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **256**
# - LEARNING RATE: 0.0001
# - FEATURE DIM: 1024
# - NUM_HEAD: 8

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 256 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 8
# Out:
# 25
# 2025-01-08 07:52:24.288343: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-08 07:52:24.386843: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-08 07:52:24.422221: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-08 07:52:24.658406: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-08 07:52:25.804421: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# result directory: ../../results/GUMI_T_3/False_False_False_0_32_4_31_25_256_0.0001_1024_8/
# 100%|█████████████████████████████████| 668970/668970 [04:48<00:00, 2319.57it/s]
# 100%|█████████████████████████████| 2135982/2135982 [00:02<00:00, 716887.82it/s]
# 100%|█████████████████████████████| 2051435/2051435 [00:02<00:00, 993317.43it/s]
# 学習に用いる大喜利の数: 2030920
#  検証に用いる大喜利の数: 20515
#  使用する画像の数: 244286
#  単語の種類: 16705
# 100%|███████████████████████████████| 244286/244286 [00:00<00:00, 340412.54it/s]
# 100%|█████████████████████████████| 2030920/2030920 [00:06<00:00, 326480.85it/s]
# num data: 2030920
# 100%|█████████████████████████████████| 20515/20515 [00:00<00:00, 742167.40it/s]
# num data: 20515
# Epoch 1/25: 100%|█| 7934/7934 [1:12:05<00:00,  1.83it/s, train_loss=4.62, train_
# Evaluating: 100%|█| 81/81 [00:36<00:00,  2.21it/s, test_loss=4.15, test_accuracy
# Epoch: 1/25, Train Loss: 4.6218, Train Accuracy: 0.2729, Test Loss: 4.1505, Test Accuracy: 0.3089
# -------------------------
# Epoch 2/25: 100%|█| 7934/7934 [1:26:06<00:00,  1.54it/s, train_loss=3.98, train_
# Evaluating: 100%|█| 81/81 [00:51<00:00,  1.56it/s, test_loss=3.96, test_accuracy
# Epoch: 2/25, Train Loss: 3.9804, Train Accuracy: 0.3207, Test Loss: 3.9569, Test Accuracy: 0.3264
# -------------------------
# Epoch 3/25: 100%|█| 7934/7934 [1:15:04<00:00,  1.76it/s, train_loss=3.77, train_
# Evaluating: 100%|█| 81/81 [00:54<00:00,  1.49it/s, test_loss=3.88, test_accuracy
# Epoch: 3/25, Train Loss: 3.7711, Train Accuracy: 0.3389, Test Loss: 3.8801, Test Accuracy: 0.3337
# -------------------------
# Epoch 4/25: 100%|█| 7934/7934 [1:11:29<00:00,  1.85it/s, train_loss=3.63, train_
# Evaluating: 100%|█| 81/81 [00:35<00:00,  2.26it/s, test_loss=3.86, test_accuracy
# Epoch: 4/25, Train Loss: 3.6340, Train Accuracy: 0.3514, Test Loss: 3.8570, Test Accuracy: 0.3374
# -------------------------
# Epoch 5/25: 100%|█| 7934/7934 [1:19:08<00:00,  1.67it/s, train_loss=3.53, train_
# Evaluating: 100%|█| 81/81 [00:36<00:00,  2.25it/s, test_loss=3.86, test_accuracy
# Epoch: 5/25, Train Loss: 3.5280, Train Accuracy: 0.3616, Test Loss: 3.8551, Test Accuracy: 0.3385
# -------------------------
# Epoch 6/25: 100%|█| 7934/7934 [1:17:29<00:00,  1.71it/s, train_loss=3.44, train_
# Evaluating: 100%|█| 81/81 [00:36<00:00,  2.24it/s, test_loss=3.86, test_accuracy
# Epoch: 6/25, Train Loss: 3.4397, Train Accuracy: 0.3704, Test Loss: 3.8599, Test Accuracy: 0.3385
# -------------------------
# Epoch 7/25:  13%|▏| 1003/7934 [09:54<1:30:44,  1.27it/s, train_loss=3.39, train_

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: 32
# - LEARNING RATE: 0.0001
# - FEATURE DIM: 1024
# - NUM_HEAD: 8

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 32 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 8

# %% [markdown]
# # 2025/1/6

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **128**
# - LEARNING RATE: 0.0001
# - FEATURE DIM: 1024
# - NUM_HEAD: 8

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 128 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 8

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: 512
# - LEARNING RATE: 0.001
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 512 \
    --learning_rate 0.001 \
    --feature_dim 1024 \
    --num_heads 4
# Out:
# 22

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **1024**
# - LEARNING RATE: 0.001
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 1024 \
    --learning_rate 0.001 \
    --feature_dim 1024 \
    --num_heads 4

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **256**
# - LEARNING RATE: 0.001
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 256 \
    --learning_rate 0.001 \
    --feature_dim 1024 \
    --num_heads 4

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: 512
# - LEARNING RATE: **0.0001**
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 512 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 4

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **128**
# - LEARNING RATE: **0.0001**
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 128 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 4
# Out:
# 22
# 2025-01-01 16:05:15.435582: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-01 16:05:15.588423: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-01 16:05:15.630806: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-01 16:05:15.933524: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-01 16:05:17.033499: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# result directory: ../../results/GUMI_T/False_False_False_0_32_4_31_25_128_0.0001_1024_4/
#  39%|████████████▊                    | 260451/668970 [02:36<04:06, 1654.64it/s]
