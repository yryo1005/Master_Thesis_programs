# %%
import os
import json
import numpy as np
import shutil
import argparse
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
from torch.utils.data import Dataset, DataLoader
import torchvision.models as models
import torchvision.transforms as transforms

# %%
# 大喜利生成モデルのクラス
class BokeGeneratorModel(nn.Module):
    def __init__(self, num_word, image_feature_dim, sentence_length, feature_dim = 1024):
        """
            num_word: 学習に用いる単語の総数
            image_feature_dim: 画像の特徴量の次元数
            sentence_length: 入力する文章の単語数
            feature_dim: 特徴量次元数
        """
        super(BokeGeneratorModel, self).__init__()
        self.num_word = num_word
        self.image_feature_dim = image_feature_dim
        self.sentence_length = sentence_length
        self.feature_dim = feature_dim
        
        self.fc1 = nn.Linear(image_feature_dim, feature_dim)
        self.embedding = nn.Embedding(num_word, feature_dim, padding_idx = 0)
        self.lstm = nn.LSTM(input_size = feature_dim, hidden_size = feature_dim, 
                            batch_first = True)
        self.fc2 = nn.Linear(feature_dim + feature_dim, 2 * feature_dim)
        self.fc3 = nn.Linear(2 * feature_dim, 2 * feature_dim)
        self.fc4 = nn.Linear(2 * feature_dim, num_word)
    
    # LSTMの初期値は0で，画像の特徴量と文章の特徴量を全結合層の前で結合する
    def forward(self, image_features, sentences):
        """
            image_features: 画像の特徴量
            sentences: 入力する文章
        """
        x1 = F.leaky_relu(self.fc1(image_features))
        x1 = x1.unsqueeze(1).repeat(1, self.sentence_length, 1)

        x2 = self.embedding(sentences)
        x2, _ = self.lstm(x2)

        x = torch.cat((x1, x2), dim = -1)
        x = F.leaky_relu(self.fc2(x))
        x = F.leaky_relu(self.fc3(x))

        return self.fc4(x)

# %%
class ImageEncoder(nn.Module):
    def __init__(self, image_feature_dim):
        """
            image_feature_dim: 
        """
        super(ImageEncoder, self).__init__()

        self.conv1 = nn.Conv2d(3, 32, kernel_size = 3, stride = 2, padding = 1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size = 3, stride = 2, padding = 1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size = 3, stride = 2, padding = 1)
        self.conv4 = nn.Conv2d(128, 256, kernel_size = 3, stride = 2, padding = 1)

        self.fc1 = nn.Linear(16384, 16384)
        self.fc2 = nn.Linear(16384, image_feature_dim)
    
    def forward(self, images):
        x = F.leaky_relu( self.conv1(images) )
        # 32, 64, 64
        x = F.leaky_relu( self.conv2(x) )
        # 64, 32, 32
        x = F.leaky_relu( self.conv3(x) )
        # 128, 16, 16
        x = F.leaky_relu( self.conv4(x) )
        # 256, 8, 8

        x = nn.Flatten()(x)
        x = F.leaky_relu(self.fc1(x))
        return F.leaky_relu(self.fc2(x))

class ImageDecoder(nn.Module):
    def __init__(self, image_feature_dim):
        """
            image_feature_dim: 
        """
        super(ImageDecoder, self).__init__()

        self.fc1 = nn.Linear(image_feature_dim, 16384)

        self.deconv1 = nn.ConvTranspose2d(256, 128, kernel_size = 3, stride = 2, padding = 1, output_padding = 1)
        self.deconv2 = nn.ConvTranspose2d(128, 64, kernel_size = 3, stride = 2, padding = 1, output_padding = 1)
        self.deconv3 = nn.ConvTranspose2d(64, 32, kernel_size = 3, stride = 2, padding = 1, output_padding = 1)
        self.deconv4 = nn.ConvTranspose2d(32, 32, kernel_size = 3, stride = 2, padding = 1, output_padding = 1)
        
        self.conv1 = nn.Conv2d(32, 3, kernel_size = 3, stride = 1, padding = 1)
    
    def forward(self, image_features):
        x = F.leaky_relu(self.fc1(image_features))
        x = nn.Unflatten(1, (256, 8, 8))(x)
        # 256, 8, 8

        x = F.leaky_relu( self.deconv1(x) )
        # 128, 16, 16
        x = F.leaky_relu( self.deconv2(x) )
        # 64, 32, 32
        x = F.leaky_relu( self.deconv3(x) )
        # 32, 64, 64
        x = F.leaky_relu( self.deconv4(x) )
        # 32, 128, 128
        return nn.Sigmoid()( self.conv1(x) )
        # 3, 128, 128

class Autoencoder(nn.Module):
    def __init__(self, image_feature_dim):
        """
            image_feature_dim: 
        """
        super(Autoencoder, self).__init__()

        self.encoder = ImageEncoder(image_feature_dim)
        self.decoder = ImageDecoder(image_feature_dim)
    
    def forward(self, images):
        return self.decoder( self.encoder(images) )

# %%
# 大喜利生成AI
class GUMI_AE:
    def __init__(self, weight_path, ae_weight_path, index_to_word, sentence_length, feature_dim = 1024, ae_feature_dim = 16384):
        """
            weight_path: 大喜利適合判定モデルの学習済みの重みのパス
            ae_weight_path: 
            index_to_word: 単語のID: 単語の辞書(0:<PAD>, 1:<START>, 2:<END>)
            sentence_length: 入力する文章の単語数
            feature_dim: 特徴量次元数
            ae_feature_dim: 
        """
        self.index_to_word = index_to_word
        self.sentence_length = sentence_length

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.boke_generate_model = BokeGeneratorModel(
                                        num_word = len(index_to_word), 
                                        image_feature_dim = ae_feature_dim, 
                                        sentence_length = sentence_length, 
                                        feature_dim = feature_dim)
        self.boke_generate_model.load_state_dict(torch.load(weight_path))
        self.boke_generate_model.to(self.device)
        self.boke_generate_model.eval()

        self.autoencoder = Autoencoder(image_feature_dim = ae_feature_dim)
        self.autoencoder.load_state_dict(torch.load(ae_weight_path))
        self.encoder = self.autoencoder.encoder
        self.encoder = self.encoder.to(self.device)
        self.encoder.eval()

        # 画像の前処理
        self.image_preprocesser = transforms.Compose([
            transforms.Resize((128, 128)),
            transforms.ToTensor(),
        ])
    
    def __call__(self, image_path, argmax = False, top_k = 5):
        """
            image_path: 大喜利を生成したい画像のパス
            argmax: Trueなら最大確率の単語を選ぶ, FalseならTop-Kサンプリングを行う
            top_k: Top-Kサンプリング時に考慮する単語の数
        """
        image = Image.open(image_path)
        preprocessed_image = self.image_preprocesser(image).to(self.device)
        image_feature = self.encoder( preprocessed_image.unsqueeze(0) ) # (1, 2048)
        
        generated_text = [1] # <START>トークン
        for i in range(1, self.sentence_length):
            tmp = generated_text + [0] * (self.sentence_length - i) # Padding
            tmp = torch.Tensor(np.array(tmp)).unsqueeze(0).to(self.device).to(dtype=torch.int32) # (1, sentence_length)
            pred = self.boke_generate_model(image_feature, tmp) # (1, sentence_length, num_word)
            target_pred = pred[0][i - 1]

            if argmax:
                # 最大確率の単語を選ぶ
                chosen_id = torch.argmax(target_pred).item()
            else:
                # Top-Kサンプリング
                top_k_probs, top_k_indices = torch.topk(target_pred, top_k)
                top_k_probs = torch.nn.functional.softmax(top_k_probs, dim = -1)
                chosen_id = np.random.choice(top_k_indices.detach().cpu().numpy(), 
                                             p = top_k_probs.detach().cpu().numpy())
            
            generated_text.append(chosen_id)
            if chosen_id == 2:
                break
        
        generated_sentence = ""
        for I in generated_text[1:-1]:
            generated_sentence += self.index_to_word[I]
        return generated_sentence

# %%
with open('/home/user/workspace/Master_Thesis/results/GUMI_AMAE/False_False_False_0_32_4_31_128_128_25_32_0.0001_16384_1000.0_3_3_25_64_0.0001_1024/index_to_word.json', 'r') as f:
    index_to_word = json.load(f)

index_to_word = {
    int(K): V for K, V in index_to_word.items()
}

# %%
model = GUMI_AE(weight_path = '/home/user/workspace/Master_Thesis/results/GUMI_AMAE/False_False_False_0_32_4_31_128_128_25_32_0.0001_16384_1000.0_3_3_25_64_0.0001_1024/best_model.pth',
                ae_weight_path = f"/home/user/workspace/Master_Thesis/results/Augmix_Autoencoder/False_False_False_0_32_4_31_128_128_25_32_0.0001_16384_1000.0_3_3/best_model.pth",
                index_to_word = index_to_word,
                sentence_length = 32, 
                feature_dim = 1024, 
                ae_feature_dim = 16384)
# Out:
# <ipython-input-4-e24bc32e483f>:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.boke_generate_model.load_state_dict(torch.load(weight_path))
# <ipython-input-4-e24bc32e483f>:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.autoencoder.load_state_dict(torch.load(ae_weight_path))

# %%
with open("generated_ohgiri.json", "r") as f:
    datas = json.load(f)

# %%
for D in tqdm(datas):
    D["GUMI_AMAE_1000.0"] = model(f"../../datas/boke_image/{D['image_number']}.jpg")
# Out:
# 100%|██████████| 200/200 [00:06<00:00, 28.93it/s]

# %%
datas
# Out:
# [{'image_number': 821461,
#   'human': 'やる気あんの？',
#   'star': 0,
#   'caption': '暗い部屋で他人と話している男',
#   'GUMI_AMAE_100.0': '「俺のプリン食べたやろー！」',
#   'GUMI_AMAE_10.0': 'この後、彼は見た',
#   'GUMI_AMAE_1.0': '「お前の母ちゃん、出ベソ！」',
#   'GUMI_T_3': '「お前、何の話してるか分かってんだよ？」',
#   'Neural_Joking_Machine': '「あの、すみません。道を聞いただけで、何か変なものがさ～」',
#   'llama': '暗い部屋で他人と話している男画像に対して一言。',
#   'GUMI_AE': 'あ〜あ〜。また派手な人が出てきたな〜…',
#   'GUMI_AMAE_1000.0': 'この中に１人妹がいる。'},
#  {'image_number': 100060,
#   'human': 'そんな事より緑が豊か',
#   'star': 0,
#   'caption': '多数のタイヤがフィールドに存在している。',
#   'GUMI_AMAE_100.0': '「お前は、この戦いにはついてこれそう」「いやいや、そちらはプライドも捨てちゃいまええやろ」',
#   'GUMI_AMAE_10.0': 'え、俺の子？',
#   'GUMI_AMAE_1.0': '「おい、お前ら、俺の靴磨き返せコラァ！」',
#   'GUMI_T_3': '「「「「「あ～あ。あの、あの、もうちょっと…」」」」',
#   'Neural_Joking_Machine': 'この惑星の住人は、去年のゴルフボールだけが連鎖',
#   'llama': 'フィールドを走行するたくさんのタイヤ',
#   'GUMI_AE': '「お前は俺を怒らせた・・・」と言われたので。',
#   'GUMI_AMAE_1000.0': '「俺、この戦争が終わったらゲートボールに行ってやる」'},
#  {'image_number': 465363,
#   'human': '人々は彼をこう呼ぶ！ルンペンと！',
#   'star': 0,
#   'caption': '女性がを持って通りを歩いている姿。',
#   'GUMI_AMAE_100.0': '「俺、この戦争が終わったら結婚するんだ」と言った結果',
#   'GUMI_AMAE_10.0': '「おーい、こっちだ！」',
#   'GUMI_AMAE_1.0': '「お前の席ねぇから」',
#   'GUMI_T_3': '「俺は、海賊王なんだ」',
#   'Neural_Joking_Machine': '「あのー、僕が落ちてきました。」と言っているが、どうやら騙されたようだ。',
#   'llama': '女性が片手に持って通りを歩いている姿。画像に対して一言。',
#   'GUMI_AE': '「あー、なるほどね。このくらいの大きさでシゴくよー」',
#   'GUMI_AMAE_1000.0': 'お父さん、お母さん、僕たち結婚して下さい！'},
#  {'image_number': 102671,
#   'human': '「眠れないの？じゃ絵本読んであげるね。」…全然眠れません。それどころか起きちゃってます。',
#   'star': 3,
#   'caption': 'ベッドに座っている白いランジェリーの女性',
#   'GUMI_AMAE_100.0': 'お前、見込みあり',
#   'GUMI_AMAE_10.0': 'お気に入りの、、、',
#   'GUMI_AMAE_1.0': '「お前頭大丈夫？」',
#   'GUMI_T_3': 'こんな感じでいーっと…。',
#   'Neural_Joking_Machine': 'お母さん、この人、昨日のことは内緒ね',
#   'llama': '「パンツは履いてないです」',
#   'GUMI_AE': '「あー、なるほどね～…なるほどね。」',
#   'GUMI_AMAE_1000.0': 'この子、誰の頭がおっさんだったのも？'},
#  {'image_number': 625026,
#   'human': '電車を降りた事に気付いてない。',
#   'star': 0,
#   'caption': '建物の前で踊っている老婆',
#   'GUMI_AMAE_100.0': 'お前が俺の親父そっくりでんなっしぃぃぃぃ！',
#   'GUMI_AMAE_10.0': '…………………',
#   'GUMI_AMAE_1.0': '「お客様、お支払いは現金ですか？延長お願いしま～す」',
#   'GUMI_T_3': '「よっしゃー！相撲取ってー！」',
#   'Neural_Joking_Machine': '「お前ら全員、ケツの青い柱を引き回せ！！」',
#   'llama': '老婆は何かの儀式を行っているようだ。',
#   'GUMI_AE': 'お父さん、お母さん、お母さんあたし。どこで遊んでたの？',
#   'GUMI_AMAE_1000.0': '「この辺りで怪しい者ではごさいません。さぁ、無事召し上がってください」'},
#  {'image_number': 634136,
#   'human': '人間って意外とオイシイ～',
#   'star': 0,
#   'caption': '口を開けた黒いレスラー。',
#   'GUMI_AMAE_100.0': 'お前ん家の母ちゃんデベソー',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': 'あどでぇー、僕ねぇー',
#   'GUMI_T_3': '「あどで～」って言った後に点数をつけてもらえない',
#   'Neural_Joking_Machine': 'この顔で卒業したら、この顔になる癖がある',
#   'llama': '大喜利のお題:口を開けた黒いレスラー。画像に対して一言。↓レスラーの顔が、顔の形に開いた口がついてる。',
#   'GUMI_AE': 'このボケが評価１だったら☆１つくれるんだよね',
#   'GUMI_AMAE_1000.0': '「え？これ食べていいの？」'},
#  {'image_number': 379834,
#   'human': 'これからヤル気スイッチを探してみたいと思います',
#   'star': 0,
#   'caption': 'マイクを持ったスーツを着た男性',
#   'GUMI_AMAE_100.0': '「この紋所が目に入らぬか！」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「あ、それツモった。」',
#   'GUMI_T_3': '「お前の乳輪はそこにあるのにぃぃ～♪」「お前の乳首は俺のだよ！」',
#   'Neural_Joking_Machine': 'この子、私の子じゃない。',
#   'llama': 'このお題には正解がありません。',
#   'GUMI_AE': '「俺が先を押さえてる間に、お前の味方が撃たれた！」「いや俺が言った奴死刑で',
#   'GUMI_AMAE_1000.0': '左から順にしなことを言う二人'},
#  {'image_number': 8991,
#   'human': 'ねえあなた、シャツに口紅ついてるわよ',
#   'star': 0,
#   'caption': '兵士がボートで洗濯をしている様子',
#   'GUMI_AMAE_100.0': '「お前の母ちゃんでべそ！」',
#   'GUMI_AMAE_10.0': 'この先、俺の下に何か生まれた',
#   'GUMI_AMAE_1.0': '「お前、見込みアリ。ワシが守ってやるよ。」',
#   'GUMI_T_3': '押すなよ！絶対押すなよ！',
#   'Neural_Joking_Machine': '「お前が俺を飼っているんじゃない、お前は何がしたいんだ！！」',
#   'llama': '「おめぇら、戦争終わったぞ」',
#   'GUMI_AE': '「この中にスパイをいれろ！」',
#   'GUMI_AMAE_1000.0': '俺は人間を止められている。仲間にしますか？はい→いいえ'},
#  {'image_number': 98010,
#   'human': '冷蔵庫に貼りついてる磁石',
#   'star': 1,
#   'caption': '空に飛び込む黒いズボンとシャツを着た男',
#   'GUMI_AMAE_100.0': '「俺が支えてるうちに早く行け！」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前、何も着とらんやんけ」',
#   'GUMI_T_3': '「今日は、この辺から、この辺でドロンさせていただきます。」「・・・」',
#   'Neural_Joking_Machine': '「お前の家燃やしたろか？」',
#   'llama': '空を飛びたい男',
#   'GUMI_AE': '「お前、今、何か書いてあるけど？」',
#   'GUMI_AMAE_1000.0': '「俺は、俺を止める」「お前は虎だ！」'},
#  {'image_number': 186512,
#   'human': 'おならを可視化してみた',
#   'star': 0,
#   'caption': 'リンゴの基調講演者',
#   'GUMI_AMAE_100.0': '「俺の方が黒い」',
#   'GUMI_AMAE_10.0': '何も無かった',
#   'GUMI_AMAE_1.0': 'お前の席、ねぇから！',
#   'GUMI_T_3': 'この時、彼は悟った。彼はまだ、この世の中に残らないことはなかった。',
#   'Neural_Joking_Machine': '今日から夏休み〜',
#   'llama': 'リンゴの基調講演者画像に対して一言。',
#   'GUMI_AE': '「お前が先にすべり消されたんじゃ」',
#   'GUMI_AMAE_1000.0': 'お前ら、俺の事をチキン野郎と言って、それを否定してるのは！'},
#  {'image_number': 678875,
#   'human': '隠れているリーゼントを探せ！',
#   'star': 0,
#   'caption': 'の中の2匹の猿の白黒図',
#   'GUMI_AMAE_100.0': '俺の頭の中',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': 'お前、俺の顔見て笑っただろ',
#   'GUMI_T_3': '俺は、住む家じゃねぇ',
#   'Neural_Joking_Machine': '俺は、お前が食ってるんだよ',
#   'llama': '猿が二匹、猿が二匹、サルのような何か。',
#   'GUMI_AE': 'この写真を撮った人は☆みっつ',
#   'GUMI_AMAE_1000.0': '昨日助けて頂いたマリモです'},
#  {'image_number': 225896,
#   'human': '俺のツノ触ったのはこの手か？',
#   'star': 0,
#   'caption': 'スーツを着た男と手を振っている子供',
#   'GUMI_AMAE_100.0': '「お前の敗けだ。まずは手を使え。」',
#   'GUMI_AMAE_10.0': '………',
#   'GUMI_AMAE_1.0': 'お前、何で俺の服着てるの？',
#   'GUMI_T_3': '俺、女だったら女だったのに、女だったんだ。',
#   'Neural_Joking_Machine': 'ちょっ！！ちょっ！！ちょっ！ちょっ！ちょっ！！ちょっ待っ！！ちょっ、ちょっ！ちょっ！ちょっ、ちょっ待っ！',
#   'llama': '画像に対する一言ボケ',
#   'GUMI_AE': 'この子、うちで飼ってもいいかな。',
#   'GUMI_AMAE_1000.0': '「俺が先に並んでいたのに、なんでお前のプリン食うたん！」'},
#  {'image_number': 433724,
#   'human': '平然としていたはずなのに、親友に趣味がばれた',
#   'star': 0,
#   'caption': 'ピンク色の髪に青い目を持つ少女。',
#   'GUMI_AMAE_100.0': '「お前の母ちゃんデベソー」',
#   'GUMI_AMAE_10.0': 'お気に入りのお店の下で寝てた',
#   'GUMI_AMAE_1.0': '「お前にサンが救えるか？」',
#   'GUMI_T_3': '「私は外にサッと塗る派」',
#   'Neural_Joking_Machine': 'この後、口から出血することを繰り返した',
#   'llama': 'あ〜、この子、きっと目が悪いんだろうな。',
#   'GUMI_AE': '私の方が可愛いいもんじゃないんです',
#   'GUMI_AMAE_1000.0': 'この画像は削除されました。彼らはあなたのもとから地球となったのだ。'},
#  {'image_number': 776260,
#   'human': 'バタ子「平和って退屈ね」',
#   'star': 0,
#   'caption': '犬と2人のシェフを持つ漫画のキャラクター',
#   'GUMI_AMAE_100.0': '「お父さん、僕、大きくなったら漁師になるんだ。」',
#   'GUMI_AMAE_10.0': 'え、この人の顔',
#   'GUMI_AMAE_1.0': '「もう、お腹いっぱいだから、もう少しですよ。」',
#   'GUMI_T_3': 'バタ子が新しい顔を焼いてるのに、まだお年玉をあげてもらえない',
#   'Neural_Joking_Machine': '「お前、何でワシの顔食ったん？」「いや、食えへんよ」',
#   'llama': '#ここに面白いボケを書きます',
#   'GUMI_AE': 'この指止まれって言ったら笑った',
#   'GUMI_AMAE_1000.0': '「お、おい！！お前の頭はおかしいだろ、こそこそ！！」'},
#  {'image_number': 227567,
#   'human': '良い砂風呂だったが、２分くらいしか楽しめなかった',
#   'star': 0,
#   'caption': 'スーツを着て地面に座っている男性',
#   'GUMI_AMAE_100.0': '「お前の身長こんくらいだ」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '怪獣に懐かれてしまったので、もう帰ろうと思っている',
#   'GUMI_T_3': 'ウルトラの星では、地球を救う',
#   'Neural_Joking_Machine': 'あ、ごめん、俺今日シフト入ったから今日休みだった',
#   'llama': 'スーツを着て地面に座っている男性画像に対して一言。',
#   'GUMI_AE': 'お父さん、お母さんあなたのお母さんなの…',
#   'GUMI_AMAE_1000.0': '「お前の母ちゃんでべそって！」『いや、だから、、、』'},
#  {'image_number': 430533,
#   'human': 'べーつる',
#   'star': 0,
#   'caption': '眼鏡をかけ、白いシャツを着た男性。',
#   'GUMI_AMAE_100.0': '「この子、私より太い蝶になるのよ」',
#   'GUMI_AMAE_10.0': 'この後、どうしました',
#   'GUMI_AMAE_1.0': '「この人痴漢です」と言われた',
#   'GUMI_T_3': '「お前の髪、薄くなってきただろ？」',
#   'Neural_Joking_Machine': '「俺が犯人だって証拠がどこに入ったのか？」と聞かれたので、否定を見計らっている',
#   'llama': '男性が眼鏡を外して「いやー、よく見たら全然イケメンじゃないな」',
#   'GUMI_AE': 'この人誰なのかしら？',
#   'GUMI_AMAE_1000.0': '「お前、口クサっ！」'},
#  {'image_number': 747774,
#   'human': 'ギックリ腰になった時に宅急便が来たので慌てて取りに行く。',
#   'star': 2,
#   'caption': '女性が階段をバックにひっくり返す',
#   'GUMI_AMAE_100.0': '「お前の家、ホコリだらけだぜ」と言って、お父さんが出てきた',
#   'GUMI_AMAE_10.0': '「お前ら！何か変な物見えてんぞ」',
#   'GUMI_AMAE_1.0': 'この後、スタッフ一同でおいしくいただきました',
#   'GUMI_T_3': '階段を登って降りていった',
#   'Neural_Joking_Machine': '「この電車通勤で、来週も観てくれるかな」',
#   'llama': '階段の昇り方が分からなくなった',
#   'GUMI_AE': '「お父さん、お母さんが僕を捨てたでしょ」',
#   'GUMI_AMAE_1000.0': '「この問題、分かるよね？」「うん。」'},
#  {'image_number': 171256,
#   'human': 'いともたやすく行われるえげつない行為',
#   'star': 0,
#   'caption': '窓から猫がぶら下がっている',
#   'GUMI_AMAE_100.0': '「俺たち人間に進化することになったよ！」「俺たちもいずれは仲良くやってあげんて」',
#   'GUMI_AMAE_10.0': 'ん？この中におれのお父さんの、お母さん？',
#   'GUMI_AMAE_1.0': '「ご主人、ご主人さまぁ、お嬢さん、お逃げなさい」',
#   'GUMI_T_3': '「俺を置いて先に行け！」って言われてから、そのまま出ていった瞬間に発砲された',
#   'Neural_Joking_Machine': 'あ、お母さん？お父さん、今日はまたマグロの敷き渡してるところ。',
#   'llama': '窓から猫がぶら下がっている画像に対して一言。',
#   'GUMI_AE': 'お前も食え',
#   'GUMI_AMAE_1000.0': '飼い主に飼い主に似るっていうなら、猫じゃらしはやしにいくよ。'},
#  {'image_number': 127905,
#   'human': '意地張って飛び出して来ちゃったけど、お前は分かってくれるよな。（・・自分に連れて来られただけやけど。）',
#   'star': 0,
#   'caption': '犬とドックに座っている少年',
#   'GUMI_AMAE_100.0': '「この子は私が守るもの」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前の席、ねーから！」',
#   'GUMI_T_3': '俺の背中に乗っかってるヤツ、絶対に行かない',
#   'Neural_Joking_Machine': '「おいおい、そんなに怒るなよ？」',
#   'llama': '少年は犬に食われた。',
#   'GUMI_AE': 'お前、俺を見て震えているだと！？',
#   'GUMI_AMAE_1000.0': 'この中にお父さんとお母さんはいませーん。'},
#  {'image_number': 822771,
#   'human': 'バナナと言ったら黄色',
#   'star': 0,
#   'caption': 'ドラゴンボールZ -サイヤ人vsカイ',
#   'GUMI_AMAE_100.0': 'お前、うまそうだな',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前の母ちゃん、、、、、、」',
#   'GUMI_T_3': '「あっ！あっ！」',
#   'Neural_Joking_Machine': '俺の手臭い？',
#   'llama': 'お前はもう死んでいる。',
#   'GUMI_AE': 'お腹がすいた時の表情',
#   'GUMI_AMAE_1000.0': 'あ、これお前のじゃない！？'},
#  {'image_number': 861708,
#   'human': 'ずっと見てると目が開くよ！',
#   'star': 0,
#   'caption': '椅子に座っているのは、あごひげとあごひげを生やした男性。',
#   'GUMI_AMAE_100.0': '「お前は何をしに来たんだよ！」と言われた',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': 'おじいちゃん、それドロップちゃう。',
#   'GUMI_T_3': '「お前、鼻が高いのってどうやってやるんだ？」',
#   'Neural_Joking_Machine': 'この顔にピンときたら１１０番',
#   'llama': '椅子に座っているのは、あごひげとあごひげを生やした男性。画像に対して一言。↓椅子に座っているのは、あごひげとあごひげを生やした男性。画像に対して一言。↓椅子に',
#   'GUMI_AE': '「あ～、やっぱりノッチですかね？」「いや、ちょっと用事思い出す」',
#   'GUMI_AMAE_1000.0': 'お前の顔、この程度か'},
#  {'image_number': 216654,
#   'human': '2アウトー‼',
#   'star': 0,
#   'caption': 'ヒラリー・クリントンが平和の印を打っている',
#   'GUMI_AMAE_100.0': '俺は今、猛烈に感動している！',
#   'GUMI_AMAE_10.0': '(()',
#   'GUMI_AMAE_1.0': '「あー、またつまらないボケ投稿して寝たわー」',
#   'GUMI_T_3': '「私が証明です！」',
#   'Neural_Joking_Machine': 'お客様、レジを通してない商品がありますよね？',
#   'llama': 'ヒラリー・クリントンが平和の印を打っている画像に対して一言。',
#   'GUMI_AE': 'この人が僕をいじめたのは',
#   'GUMI_AMAE_1000.0': '俺の手相も～'},
#  {'image_number': 397951,
#   'human': 'おじがわら',
#   'star': 0,
#   'caption': '耳に手をかけた年配の男性の絵画',
#   'GUMI_AMAE_100.0': '「お前の好きな子のスキマは預かった」',
#   'GUMI_AMAE_10.0': 'お前ら・・・',
#   'GUMI_AMAE_1.0': '「おい、見ろよ！あの子のパンツ見えてるぞ！」',
#   'GUMI_T_3': '孫が欲しい♪',
#   'Neural_Joking_Machine': '「この指と〜まれ」と言った途端に、この表情。',
#   'llama': '耳に手をかけた年配の男性の絵画画像に対して一言。',
#   'GUMI_AE': 'あ、もしもし？',
#   'GUMI_AMAE_1000.0': '「私、実はオネェ」'},
#  {'image_number': 753960,
#   'human': '上司の説教が終わり振り返った顔',
#   'star': 3,
#   'caption': '口を開けた事務所にいる女性',
#   'GUMI_AMAE_100.0': '「お前の母ちゃんデベソー」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「え？お前が俺のプリン食ったの？」',
#   'GUMI_T_3': 'この顔で見てくる。',
#   'Neural_Joking_Machine': 'この後、彼は一生懸命尿下段移植を受けた',
#   'llama': '「社長が口を動かしていると、秘書が口を開ける」',
#   'GUMI_AE': '(このガキ…………)',
#   'GUMI_AMAE_1000.0': '俺が話しかけるからジャマして。'},
#  {'image_number': 101680,
#   'human': '「オイラのプライバシーが～」「バカ来るよ」',
#   'star': 0,
#   'caption': '草の中に2匹のヒグマが立っている',
#   'GUMI_AMAE_100.0': '「お前、俺のプリン食ったろ？」「いや、おまえが」',
#   'GUMI_AMAE_10.0': '「お前の母ちゃん、、、',
#   'GUMI_AMAE_1.0': '「お前、今から、この前の走者を爆破してやってんだ」',
#   'GUMI_T_3': '「あのさ、くまもんって、、」「えっ？！」',
#   'Neural_Joking_Machine': '「おい！あの柵は間に合わねぇぞ！」「いや、熊ならあっちに逃げましたよ！」',
#   'llama': '草の中に2匹のヒグマが立っている画像に対して一言。',
#   'GUMI_AE': '「あ、それ僕のお年玉」',
#   'GUMI_AMAE_1000.0': '「おい、あの娘の乳首の色は・・」「俺は男だ」'},
#  {'image_number': 446327,
#   'human': '泉に落ちた友達を正直に答えたら取り返しのつかないことになった',
#   'star': 0,
#   'caption': '長い髪と金色の背景を持つ男性',
#   'GUMI_AMAE_100.0': '「お前、今日は俺の奢りだ」',
#   'GUMI_AMAE_10.0': '俺の前を通った',
#   'GUMI_AMAE_1.0': '「お前の席、無ぇ！」',
#   'GUMI_T_3': 'この髪型にしてから、ずっとオシャレしてきてて、髪の毛の話題になっている',
#   'Neural_Joking_Machine': '「ええ！？これ、食ったこと無いような顔で聞いたんですけど」',
#   'llama': '「長い髪と金色の背景を持つ男性画像」に対して「一言」で「面白い」ボケを生成する',
#   'GUMI_AE': '「あ、もしもし！今の俺じゃなかったっぽいんで。」',
#   'GUMI_AMAE_1000.0': '「え？なに？何で？」'},
#  {'image_number': 800056,
#   'human': 'どれにしよっかな',
#   'star': 0,
#   'caption': '青いシャツと青いシャツを着て空を飛んでいる少年',
#   'GUMI_AMAE_100.0': '「お父さん、お母さん、僕は元気でやってます。」',
#   'GUMI_AMAE_10.0': 'お前の頭の上のボケ、誰も気づいてない',
#   'GUMI_AMAE_1.0': '「お父さん、お母さん、僕は元気にやってます。」',
#   'GUMI_T_3': 'この画像の中から選ばれし者が消しゴムのs…',
#   'Neural_Joking_Machine': '「「「「「「「「「おすーシーーー！」」」」」」」」」」」',
#   'llama': '青いシャツと青いシャツを着て空を飛んでいる少年画像に対して一言。',
#   'GUMI_AE': '「お前ら俺の頭を見てくれよ。」と言って、つい…',
#   'GUMI_AMAE_1000.0': 'お、押し倒される、、、'},
#  {'image_number': 194516,
#   'human': '誰の弟？と言われたが妹です',
#   'star': 0,
#   'caption': '女と子供付きの散歩をする少年',
#   'GUMI_AMAE_100.0': '「お前の母ちゃんスゲぇな！キュウリ食い過ぎてんねん！」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前、口くっさw」',
#   'GUMI_T_3': 'この子の将来を楽しみだな',
#   'Neural_Joking_Machine': 'この子は私が育てる。',
#   'llama': '女と子供付きの散歩をする少年が、一番好き',
#   'GUMI_AE': '「この人は僕が守る」と言った途端にこの態度',
#   'GUMI_AMAE_1000.0': '俺の頭の中'},
#  {'image_number': 187059,
#   'human': '実際の製品と異なりすぎてた',
#   'star': 0,
#   'caption': 'リンゴを乗せてラップトップを使っている男性',
#   'GUMI_AMAE_100.0': '「お前、俺の本名知ってるよ」',
#   'GUMI_AMAE_10.0': '……………………………',
#   'GUMI_AMAE_1.0': '「りんご」の名弾のマーク',
#   'GUMI_T_3': 'りんごを食べる時はリンゴと蜂蜜を与えられた。',
#   'Neural_Joking_Machine': '「俺のボケを見てくれ！と思ったやつ☆３つ」っと。',
#   'llama': '画像をよく見たら、リンゴじゃなくてラップトップのキーボードだった。',
#   'GUMI_AE': 'お前のハートを射止めたぜ！',
#   'GUMI_AMAE_1000.0': '「もうちょっと下げといて」の一点張りで、もうちょい耐えれるわ。'},
#  {'image_number': 215073,
#   'human': '困ったことはないか？と聞かれ、何もなくて困ってる人',
#   'star': 3,
#   'caption': '赤い鼻と黒い目を持つ日本の仮面。',
#   'GUMI_AMAE_100.0': '「お前の親父、俺の名前書いてるぜ！」と言った結果',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': 'お父さん！！！',
#   'GUMI_T_3': '「今日も朝帰りですか？ん～…」',
#   'Neural_Joking_Machine': '「お母さん！？」「いや、お前じゃなくて、今あたしのことエッチな目で見てたでしょ？」',
#   'llama': 'この画像がすごい人気。',
#   'GUMI_AE': '「俺、実は童てい」',
#   'GUMI_AMAE_1000.0': 'お婆さんが、またつまらぬものを斬ってしまった'},
#  {'image_number': 180039,
#   'human': 'すいません…誰か地球儀描ける人いませんか？',
#   'star': 1,
#   'caption': '浜辺に舞踏会を営む男',
#   'GUMI_AMAE_100.0': '「お前ら、今日は俺の奢りだ」「俺は、俺が先に開催したんだ」',
#   'GUMI_AMAE_10.0': 'お風呂の中',
#   'GUMI_AMAE_1.0': 'この惑星の住人は、不思議な力で奪い取った。',
#   'GUMI_T_3': '「いいか！？この後に「このボールをお腹を押さないんだ！」',
#   'Neural_Joking_Machine': '「「「「「「「あちらの方向でお願いします。」」」」」」」',
#   'llama': '浜辺でマイムマイムを踊ってはいけない',
#   'GUMI_AE': 'お前も、俺の相棒を孕んだ奴は許さん',
#   'GUMI_AMAE_1000.0': 'あの子、また戦争失敗した！'},
#  {'image_number': 404481,
#   'human': '外人2:50',
#   'star': 1,
#   'caption': '人や動物の写真のコラージュ',
#   'GUMI_AMAE_100.0': '「「「「「「「「「「「「「「「「「「「「「「「「「「「「「「',
#   'GUMI_AMAE_10.0': 'この下に入る',
#   'GUMI_AMAE_1.0': '「私は外にサッと塗ったよ」',
#   'GUMI_T_3': '「今日は顔色悪いわよ！」',
#   'Neural_Joking_Machine': '「あー、なるほど。で、何で俺だけ何で生き物なんやろ？」',
#   'llama': '#ここには面白いボケを書きます',
#   'GUMI_AE': 'お母さんあの人が私の胸張り上げオーラで固まる女が気に入ったりなんですよ',
#   'GUMI_AMAE_1000.0': 'この人痴漢です！'},
#  {'image_number': 310409,
#   'human': 'どうだ俺の脚は、細く見えるだろう？',
#   'star': 1,
#   'caption': '男の隣の階段に座っている犬',
#   'GUMI_AMAE_100.0': '「お前の席ねぇから！」',
#   'GUMI_AMAE_10.0': '「あ、目が覚めた。」',
#   'GUMI_AMAE_1.0': 'お前、何で俺にだけこんな綺麗な夕ィアンなんだよ。',
#   'GUMI_T_3': '「犬型爆弾を購入した」',
#   'Neural_Joking_Machine': '「おい、お前、今、犬の肛門の間蹴ったやろ！」',
#   'llama': '犬「おにぎりください」',
#   'GUMI_AE': 'この人誰？',
#   'GUMI_AMAE_1000.0': 'この後の展開が遺影になるとはまさにカネを否定する魔王'},
#  {'image_number': 763787,
#   'human': 'へへっ、いいだろ？僕の友達の園児が作ってくれたんだ、いくら金を出しても買えないんだぜ…',
#   'star': 0,
#   'caption': '角を持つ頭のクレイ彫刻',
#   'GUMI_AMAE_100.0': '「私の年収低すぎ！！」',
#   'GUMI_AMAE_10.0': '「……………………」',
#   'GUMI_AMAE_1.0': '「え？この状態から入れる保険があるんですか？」',
#   'GUMI_T_3': '顔を見ても顔がデカい',
#   'Neural_Joking_Machine': '「ちょっと、どこ見てんのよ！」',
#   'llama': 'その角、使えますかね？',
#   'GUMI_AE': 'あ、お母さん？',
#   'GUMI_AMAE_1000.0': 'この後彼は静かに悟りを飛んでいた'},
#  {'image_number': 860846,
#   'human': '修学旅行と聞いてたけど、着いた所が刑務所。',
#   'star': 0,
#   'caption': 'サングラスと笑顔のバスに乗った男たち',
#   'GUMI_AMAE_100.0': '「お母さん！お父さん！！」',
#   'GUMI_AMAE_10.0': '俺の顔を見て、誰も気づいてない。',
#   'GUMI_AMAE_1.0': 'お前、俺が見えるのか？',
#   'GUMI_T_3': 'お前、俺のプリン食ったろ！！',
#   'Neural_Joking_Machine': '「お前、昨日までこれ捨てたぜ」',
#   'llama': 'サングラスと笑顔のバスに乗った男たち画像に対して一言。',
#   'GUMI_AE': '「お前の母さんの胸、こぉんなもん食べるからな」',
#   'GUMI_AMAE_1000.0': 'お父さんが、実の父親だったとグズっている'},
#  {'image_number': 750799,
#   'human': '「僕たちは、魔法でこんな姿にされました」',
#   'star': 0,
#   'caption': '食事付きのテーブルに座っている2人の男性',
#   'GUMI_AMAE_100.0': '「この辺に置いてた検尿コップ知らない？」',
#   'GUMI_AMAE_10.0': 'お分かり頂けただろうか',
#   'GUMI_AMAE_1.0': '「この指を、人差し指と中指を鳴らす練習をしておく」',
#   'GUMI_T_3': '「おい、お前、お会計してんな」「おい、俺の財布持って来い」',
#   'Neural_Joking_Machine': 'お客様、当店ではお似合ちでございます',
#   'llama': '画像2枚のうち片方は、食事付きのテーブルに座っている2人の男性画像です。もう片方の画像は何ですか？',
#   'GUMI_AE': '「おい、俺が見えるのか？」',
#   'GUMI_AMAE_1000.0': '「おい、俺の筋肉。おい！」「おいっ、今蹴れよ」'},
#  {'image_number': 183936,
#   'human': 'いまさら、家の鍵を掛けたか心配になってきた。',
#   'star': 1,
#   'caption': 'マイクで歌っている女性',
#   'GUMI_AMAE_100.0': '「あ～、お前の席ねーから！！」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': 'お前の母ちゃん、でーべーそー',
#   'GUMI_T_3': 'マイクのコードを噛まれた',
#   'Neural_Joking_Machine': '「え、何？何で？俺の髪がヘビみたいに飛ぶの？」',
#   'llama': 'お前のマイクどこいった？',
#   'GUMI_AE': '「お前の母ちゃんでべそ〜」',
#   'GUMI_AMAE_1000.0': '（あの女、俺のこと好きなのか…）'},
#  {'image_number': 720167,
#   'human': 'ボス戦前にセーブ中',
#   'star': 0,
#   'caption': 'ハムスターが赤い円のあるソファーの上に座っている',
#   'GUMI_AMAE_100.0': 'この後、この後、彼が地球を救うことになる。',
#   'GUMI_AMAE_10.0': 'お前、何をしている...',
#   'GUMI_AMAE_1.0': 'この状態で分裂',
#   'GUMI_T_3': '「お客様、ソファーの上に座ってお願いいたします！」',
#   'Neural_Joking_Machine': '昨日食べた夕飯が思ってたのと違った',
#   'llama': 'ハムスターが座ってる。',
#   'GUMI_AE': 'お、お、俺の分のキビダンゴ、この株は俺の物だ。',
#   'GUMI_AMAE_1000.0': 'お母さんのお母さんだよ！'},
#  {'image_number': 4631,
#   'human': '動物の行動：狩り',
#   'star': 0,
#   'caption': '石畳通りを歩くネコとハト',
#   'GUMI_AMAE_100.0': 'お前ら、俺に逆らう者は殺れないぞ',
#   'GUMI_AMAE_10.0': '何も無い',
#   'GUMI_AMAE_1.0': 'この画像がボケてます',
#   'GUMI_T_3': 'ハト『お前、人間じゃねぇだろ？』',
#   'Neural_Joking_Machine': '「おい、俺の足を返せ」',
#   'llama': 'ネコがハトを追いかけている。',
#   'GUMI_AE': '「お前は、お前の味方はわしの子だ」',
#   'GUMI_AMAE_1000.0': '「この中に裏切り者がいる！」'},
#  {'image_number': 757543,
#   'human': 'コーラス隊が目立つ',
#   'star': 0,
#   'caption': '電光石火の前には、アニメの登場人物たちが立っている。',
#   'GUMI_AMAE_100.0': '「お前の席ねぇから！」',
#   'GUMI_AMAE_10.0': '何も思い出していない',
#   'GUMI_AMAE_1.0': '「俺のプリン食っただろ！」「いや、お前の方が…」',
#   'GUMI_T_3': '「お前ん家の換気扇すげぇぞ！」『お父さんの形見なの』',
#   'Neural_Joking_Machine': 'この中に、１人妹が入っています',
#   'llama': '電光石火の前には、アニメの登場人物たちが立っている。画像に対して一言。「電光石火の前には、アニメの登場人物たちが立っている」は、文字通りに取ると意味不明なので、「電光石火の前にアニメの登場人物たちが立っている」と読むべきである。',
#   'GUMI_AE': '「お前の好きなやつは日本一で」「ああ、俺の話はナシだ」',
#   'GUMI_AMAE_1000.0': 'お前の席ねえーからぁぁー！！'},
#  {'image_number': 446530,
#   'human': '顔で獲った銀メダル',
#   'star': 0,
#   'caption': '長い黒髪の男がカメラを見ている',
#   'GUMI_AMAE_100.0': '「お前、俺のプリン食ったろ？」',
#   'GUMI_AMAE_10.0': '‖‖‖‖',
#   'GUMI_AMAE_1.0': 'お前、俺が見えるのか？',
#   'GUMI_T_3': '「お前が、俺が見えるのか？」',
#   'Neural_Joking_Machine': 'この画像を投稿した時、どんな顔をすればいいのか分からなくなる',
#   'llama': '僕の髪が長い。',
#   'GUMI_AE': '「お前は俺を怒らせた」',
#   'GUMI_AMAE_1000.0': 'お前、俺のプリン食べた奴、、だれ？！'},
#  {'image_number': 373679,
#   'human': 'お客様だいぶこってますねぇ',
#   'star': 0,
#   'caption': 'ある男が別の男とケンカをしている',
#   'GUMI_AMAE_100.0': '「このはしわたるべからず」の看板にぶら下がってとどめ上げられたコンパス',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「あ～、お前の嫁さん、またつまらぬ物を結んでくれたから未だに使ってるんだけど、もう一度行っ',
#   'GUMI_T_3': 'お前のボケ、俺だけスルーして来い',
#   'Neural_Joking_Machine': 'この後、彼が土俵に立たなかった',
#   'llama': '「その服の柄、どうやって洗った？」',
#   'GUMI_AE': '俺、この戦争から起こるんだぜ…',
#   'GUMI_AMAE_1000.0': 'お前、顔デカイな。'},
#  {'image_number': 765561,
#   'human': '↑人形腹話術師↑',
#   'star': 0,
#   'caption': '駐車場に立っている男と少女',
#   'GUMI_AMAE_100.0': 'お前ら、この後に続け！',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前ら、さっさと帰れ」',
#   'GUMI_T_3': '「お父さんは今から旅行に行く準備をしてるよ」',
#   'Neural_Joking_Machine': '「あの、お巡りさん、この人です。」',
#   'llama': 'ボケ',
#   'GUMI_AE': 'お母さーん！お母さんが買ってもらったボール！没収よー！',
#   'GUMI_AMAE_1000.0': '俺のプリン食ったのはオマエか！'},
#  {'image_number': 225897,
#   'human': '「何食べてるの～？」「な、何も食べてないわよ。早く寝なさい！」',
#   'star': 1,
#   'caption': '枝にまつる2本のまつげ',
#   'GUMI_AMAE_100.0': '「お前ら、俺を見てろ、俺は、お前は、、、、、」',
#   'GUMI_AMAE_10.0': 'この先は行き止まり',
#   'GUMI_AMAE_1.0': '「ちょっと、男子ちゃんと歌ってよ！」',
#   'GUMI_T_3': 'カマカマってカマキリのカマがカマキリだったカマキリの巣を見つけた。',
#   'Neural_Joking_Machine': '「この子が欲しいの？」「いや私が？」「「いやいっちもぅ」」',
#   'llama': '1000年に一度の逸材',
#   'GUMI_AE': '「ちょっ、ちょっ、まっ、、、',
#   'GUMI_AMAE_1000.0': 'お前、俺の家に来んかい？'},
#  {'image_number': 829595,
#   'human': 'はい！起立！！',
#   'star': 0,
#   'caption': '椅子に座って身振りをする少女',
#   'GUMI_AMAE_100.0': 'お前の頭、湿度がたりないなぁ',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前、昨日の晩に食べた高級ワインを飲んでると油断してたよな？」「うん、おいしいよ」',
#   'GUMI_T_3': '私の年収低すぎ！',
#   'Neural_Joking_Machine': 'かわいい。もっと、保存♪',
#   'llama': '椅子に座って身振りをする少女画像に対して一言。',
#   'GUMI_AE': '「おい、お前、今俺のこと「パパ」て言った？',
#   'GUMI_AMAE_1000.0': 'ああ…間違いない使徒だ'},
#  {'image_number': 139230,
#   'human': 'デートしてたら元カレと遭遇してしまった。',
#   'star': 0,
#   'caption': 'ゴジラvs怪獣-怪獣vsゴジラ',
#   'GUMI_AMAE_100.0': '「この辺で地雷埋めたの、誰も助けないと思ってるのよねぇ」',
#   'GUMI_AMAE_10.0': '「え、私の顔の低い所に…」',
#   'GUMI_AMAE_1.0': '「「「「「「「「「「「「「「「「「「「「「「「「「「「「「「',
#   'GUMI_T_3': '「ああ、ちょっと待って！」『え？あ、お父さん…』',
#   'Neural_Joking_Machine': 'この人痴ｋ・・・',
#   'llama': 'ゴジラvs怪獣-怪獣vsゴジラ画像に対して一言。',
#   'GUMI_AE': '「お母さん、今日は何の為に俺の家作ってくれるの？」「……」',
#   'GUMI_AMAE_1000.0': 'お父さん！'},
#  {'image_number': 459610,
#   'human': 'やだ！わしの年収低すぎ!？',
#   'star': 0,
#   'caption': '雨の中に長い髭を生やした漫画家。',
#   'GUMI_AMAE_100.0': '「あ、ごめん。今の心境は何？」',
#   'GUMI_AMAE_10.0': '何か出る。',
#   'GUMI_AMAE_1.0': '「俺の屍を越えて行け」って言ったら、この格好で帰れと言われた',
#   'GUMI_T_3': 'この帽子、ワシのだぞ？',
#   'Neural_Joking_Machine': 'この子、、、、、！',
#   'llama': '長い髭が、雨に打たれて伸びる。',
#   'GUMI_AE': 'この写真のボケに星がゼロになりおそうかどうかは分かっているので、お詫びにする事にします',
#   'GUMI_AMAE_1000.0': '「お父さん、僕たち結婚しました」「それより、おじさんと遊びなさい」'},
#  {'image_number': 105875,
#   'human': 'ふっ！あなた、そんなんで私を逝かせようとしたの？',
#   'star': 1,
#   'caption': '椅子に座る女性',
#   'GUMI_AMAE_100.0': 'ああ、あの時の鶴じゃ',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「あら、い～ですね～」',
#   'GUMI_T_3': 'この後、彼が脱いだことは言うまでもない。',
#   'Neural_Joking_Machine': 'お前も痔だったのか！',
#   'llama': 'この椅子、一個五百円で譲ります。',
#   'GUMI_AE': '「お母さ〜ん…」「あ〜、、お義母さま！」',
#   'GUMI_AMAE_1000.0': 'お前、その程度のボケでいいんだよ！！！！'},
#  {'image_number': 278348,
#   'human': 'ウンコ出そうな時だけ束ねた髪をほどいて教えてくる',
#   'star': 0,
#   'caption': '大きなアフロがロッカーに座っている男性',
#   'GUMI_AMAE_100.0': '「お前の好きな女子は、俺のクチバシはデカいんだぜ」',
#   'GUMI_AMAE_10.0': '「あ、目が合った。」',
#   'GUMI_AMAE_1.0': 'あ、おひょ～～～～～！',
#   'GUMI_T_3': '髪の毛の妖精',
#   'Neural_Joking_Machine': 'この子の名前を教えてください',
#   'llama': '大きなアフロがロッカーに座っている男性画像に対して一言。',
#   'GUMI_AE': 'この写真を撮ったのは誰ですか？と聞かれて「ええ、もちろんSHPです！」って言ったらめっ',
#   'GUMI_AMAE_1000.0': 'お父ちゃんが自転車で遊んでてこないので通報して味噌汁に氷を付けて着てきた'},
#  {'image_number': 268661,
#   'human': '今からこの港を干上がらせてみたいと思います',
#   'star': 0,
#   'caption': '水の手前に立つ男。',
#   'GUMI_AMAE_100.0': '「俺が支えているから、早く逃げるんだ」',
#   'GUMI_AMAE_10.0': '………………',
#   'GUMI_AMAE_1.0': '「お前の方が、綺麗だろっ！」',
#   'GUMI_T_3': '「この辺で、全てが川に流されちゃった」',
#   'Neural_Joking_Machine': '「俺が先に行く」と言ったら、みんなが帰り支度を始めた',
#   'llama': '男「手前の水飲んでるけど、大丈夫？」',
#   'GUMI_AE': '「俺、今日も仕事の都合でさ、仕事を探そうや」',
#   'GUMI_AMAE_1000.0': '「お前はもう死んでいる」'},
#  {'image_number': 365430,
#   'human': 'つべこべ言ってるとキャーン言わせるぞ！',
#   'star': 0,
#   'caption': 'カメラに向かって指を指差している年配の男性',
#   'GUMI_AMAE_100.0': 'お前は俺を怒らせた',
#   'GUMI_AMAE_10.0': 'ん？！？',
#   'GUMI_AMAE_1.0': 'お、お前、おれの手を借りたいのか？',
#   'GUMI_T_3': 'アタックチャーンス！',
#   'Neural_Joking_Machine': '「お前が歌うんかい！」',
#   'llama': '「指差してはいけない」',
#   'GUMI_AE': '「お前、今なんつった？」',
#   'GUMI_AMAE_1000.0': 'この中に偽物がいます'},
#  {'image_number': 117452,
#   'human': '股間は真っ白にしといたんだけどな？',
#   'star': 1,
#   'caption': '白装束姿の男女の絵。',
#   'GUMI_AMAE_100.0': '「お前、俺が見えるのか？」「あれは……」',
#   'GUMI_AMAE_10.0': 'お気に入りのお気に入りのお気に入りのお気に入りのお気に入りのお気に入りの',
#   'GUMI_AMAE_1.0': '「あ、すいません。お先に頂いてます。」',
#   'GUMI_T_3': '「え？この状況から入れる保険があるんですか？」',
#   'Neural_Joking_Machine': 'この写真、お前の母ちゃん？？',
#   'llama': '白装束姿の男女の絵。画像に対して一言。',
#   'GUMI_AE': '「お客様、お食事の用意をしたいと思っておりましてよ！」',
#   'GUMI_AMAE_1000.0': 'お前の嫁さん、随分とおふくろ'},
#  {'image_number': 824228,
#   'human': '地の果てまでのろっ.てやるって言われたけどちょっと面白い',
#   'star': 2,
#   'caption': '僕は少しのスノッブだ。',
#   'GUMI_AMAE_100.0': '「この辺に地雷があるらしいから、もう少し待ってて」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「おーい、そこの君。俺の服返してくれ。」',
#   'GUMI_T_3': 'お風呂の栓抜いたら底先に入ってて行くタイプの人',
#   'Neural_Joking_Machine': '「お母さん、見に来てくれた人、ここ」',
#   'llama': '画像に対して一言。',
#   'GUMI_AE': '「お父さん、この名刺、いつまで寝てるの！？」',
#   'GUMI_AMAE_1000.0': 'この後、スタッフの「お客様の席をご覧下さい」と言われている'},
#  {'image_number': 644569,
#   'human': '屋台で買ったお面が妙に生々しい',
#   'star': 3,
#   'caption': '茶色のセーターとネクタイを着た男性',
#   'GUMI_AMAE_100.0': '「あ、あんた、オイラが見えるのかい？」',
#   'GUMI_AMAE_10.0': '「お前の家、こっちじゃねーか」',
#   'GUMI_AMAE_1.0': 'あー、もう、寝ちゃったみたい。',
#   'GUMI_T_3': '「お前の母ちゃんでーべそ！！」',
#   'Neural_Joking_Machine': 'え、何だっけ…ここまで来た！？',
#   'llama': '茶色のセーターとネクタイを着た男性画像に対して一言。',
#   'GUMI_AE': '俺が見ていない隙に、おもいっきり蹴り上げを見守る。',
#   'GUMI_AMAE_1000.0': 'この角度なら、こう'},
#  {'image_number': 866381,
#   'human': '芝がマリファナで出来ている。',
#   'star': 0,
#   'caption': '地面に横たわっているサッカー選手',
#   'GUMI_AMAE_100.0': '「俺の方が高いー！」',
#   'GUMI_AMAE_10.0': 'お前は…………………',
#   'GUMI_AMAE_1.0': 'やべっ！足つった！',
#   'GUMI_T_3': 'あ〜っ、俺のユニフォーム隠したのだれ？',
#   'Neural_Joking_Machine': '「お前も痔かーい！！」',
#   'llama': '地面に横たわっているサッカー選手画像に対して一言。',
#   'GUMI_AE': 'お、お前、俺の船酔い下手だなぁ〜。',
#   'GUMI_AMAE_1000.0': '「お母さんがお父さんの子供の時にイジメてた訳じゃないんだからね！」'},
#  {'image_number': 315745,
#   'human': '今日も指名ありませんか…？',
#   'star': 0,
#   'caption': '飲食店の男女',
#   'GUMI_AMAE_100.0': '「お前は既に包囲されている」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前は俺のモノだ！」「俺の方が先だって！」',
#   'GUMI_T_3': 'お客様、お会計の際はお茶をお願いします。',
#   'Neural_Joking_Machine': '「・・・」',
#   'llama': 'このお店は、男は入りにくいが、女は入りやすい',
#   'GUMI_AE': '「俺のプリン食ったのお前だろ！」',
#   'GUMI_AMAE_1000.0': 'お母さんに髪切ってもらうの反対'},
#  {'image_number': 749725,
#   'human': '「すごい木がいっぱい茂ってるね〜あっ！あそこを見てごらん！すごい茂ってるよ！茂りまくってるね〜」『……帰ります』',
#   'star': 1,
#   'caption': '森の中のベンチに座っている2人',
#   'GUMI_AMAE_100.0': '「お前ら、俺をダシにしたいのか？」',
#   'GUMI_AMAE_10.0': '「お前、俺の事好き？」',
#   'GUMI_AMAE_1.0': 'この後、着地をしている人に「この人痴漢です」と言われ救助され、慌てて見つかる',
#   'GUMI_T_3': '「あー！」と叫んでしまった',
#   'Neural_Joking_Machine': '俺が見えるのか？',
#   'llama': '私がベンチに座ってたら、後ろの人が私を座布団扱いした。',
#   'GUMI_AE': 'お前の家、おっきしたぞー',
#   'GUMI_AMAE_1000.0': 'お前ら…何サボってんだ？'},
#  {'image_number': 7030,
#   'human': 'は、はやくあの食い逃げをつかまえて～！',
#   'star': 0,
#   'caption': '人々の一群を飛び越えるイエスの絵',
#   'GUMI_AMAE_100.0': 'お前ら、今日は俺の家に留学生来な',
#   'GUMI_AMAE_10.0': '「お前の顔、、、、',
#   'GUMI_AMAE_1.0': 'お母さ～ん！',
#   'GUMI_T_3': '校長の話が長過ぎる',
#   'Neural_Joking_Machine': '「「「「「「「「イエッｋ★とかはいいからさ～！',
#   'llama': '「イエスは、おまえらなんかには、もったいない」',
#   'GUMI_AE': '「お前ら、この辺りではオレの股関を掘って一体何をして、誰が作った？」',
#   'GUMI_AMAE_1000.0': '「「「「「「「「お控ー！お待ちっ！！」」」」」」」」'},
#  {'image_number': 171773,
#   'human': 'シリコン入れすぎとちゃう？',
#   'star': 0,
#   'caption': '緑色のズッキーニを掲げている女性。',
#   'GUMI_AMAE_100.0': '「この子の命はひても、お前の事を忘れられない」',
#   'GUMI_AMAE_10.0': 'ん？この中に何か入っているんですか？',
#   'GUMI_AMAE_1.0': '「あー、もう、かゆいわー。」',
#   'GUMI_T_3': 'この後、彼を襲う！',
#   'Neural_Joking_Machine': 'これ、うちのペットですけど、おばあちゃん？',
#   'llama': '女性「今年はこれ、緑色のズッキーニが流行る」',
#   'GUMI_AE': 'お前が俺で、お前が俺で俺がお前？',
#   'GUMI_AMAE_1000.0': '「おい、そこのお前、早く代わりのドライフード作ってんぞ」'},
#  {'image_number': 69358,
#   'human': 'お下劣ボケ、待ってます♡',
#   'star': 2,
#   'caption': '長い黒髪に赤い上着を纏った若い女性。',
#   'GUMI_AMAE_100.0': '私は、これでも食って幸せなんだ',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「この指、めっちゃ臭い」',
#   'GUMI_T_3': '「あーあ、そのボケ最高なんだっけ？あー、はいはい。あーあーあーあーあー。」',
#   'Neural_Joking_Machine': '「あなたは、私の目を見て話しなさい！！」',
#   'llama': '長い黒髪に赤い上着を纏った若い女性。画像に対して一言。',
#   'GUMI_AE': 'お前の年収低すぎ！',
#   'GUMI_AMAE_1000.0': '私の心臓を捧げようね'},
#  {'image_number': 775171,
#   'human': 'アホの娘だということは分かる',
#   'star': 0,
#   'caption': '踊る少女のシルエット',
#   'GUMI_AMAE_100.0': '「俺のボケつまらないボケランキングで☆がついてないと思うぜ」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '銃の持ち主の悪意',
#   'GUMI_T_3': '「お客様の中に入って行きましょうか、あああああああああああ」',
#   'Neural_Joking_Machine': '「お前、昨日の晩、なに？」って言われた時の思春期',
#   'llama': '踊る少女のシルエット画像に対して一言。',
#   'GUMI_AE': '俺のムスコが擬人化した！？',
#   'GUMI_AMAE_1000.0': 'おい！俺の靴どこいったか知らん？？'},
#  {'image_number': 283420,
#   'human': '髪は死んだ細胞。でも、頭皮は生きている！「頭皮は生きているーー！」',
#   'star': 1,
#   'caption': '制服姿の大きな集団がクラッピングしている。',
#   'GUMI_AMAE_100.0': '「お前、今日は俺のライブ来てるのか？」「うん、そうだね、独りじゃないわ」',
#   'GUMI_AMAE_10.0': 'え？私の家に帰って来る？',
#   'GUMI_AMAE_1.0': '俺の服知らない？',
#   'GUMI_T_3': '「この中に一人だけスパイがいました」',
#   'Neural_Joking_Machine': 'この写真を撮っている人は☆を押してください。',
#   'llama': '画像がクラッシュした',
#   'GUMI_AE': 'この中に１人妹がいる！',
#   'GUMI_AMAE_1000.0': '「この人痴漢です」'},
#  {'image_number': 557242,
#   'human': '分かったんですよ、犯人がね',
#   'star': 0,
#   'caption': 'カーリーヘアが平面上に横たわっている男性',
#   'GUMI_AMAE_100.0': '「俺の方がフサフサだなんて、そんなのイヤ」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「この顔に免じて、私は生まれました。」',
#   'GUMI_T_3': '「今日はカレーだってよ」と聞くと、「………」と答えた瞬間この顔',
#   'Neural_Joking_Machine': 'この顔が素敵だとたまにこうなる',
#   'llama': '男性がカーリーヘアを生やし始めたきっかけ',
#   'GUMI_AE': 'お前の母ちゃん、でーべそ♪',
#   'GUMI_AMAE_1000.0': '「え？これ全部削れるの？」「……ゴクン」'},
#  {'image_number': 154957,
#   'human': '前世は右利き',
#   'star': 3,
#   'caption': '草の上に小さな犬をふりかける女',
#   'GUMI_AMAE_100.0': '「お前は何もみえへんやろ」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '俺が猫になってる！！',
#   'GUMI_T_3': '「おい待て、待て、お前にはまだ早くないか？」「ううん！！」',
#   'Neural_Joking_Machine': '「ここだ、ここが気持ちいいのか」「あぁ、そこそこぉ！」',
#   'llama': '犬をふりかけるというよりは、「犬を乗せて走ってる」感じかな',
#   'GUMI_AE': '「お父さん、この狐が俺の腹に戻って来るんだってさ！」',
#   'GUMI_AMAE_1000.0': 'お母さん！！'},
#  {'image_number': 595619,
#   'human': '和んだ後にその下の惨劇を見ることになるとは・・・',
#   'star': 0,
#   'caption': 'ポーチの上の椅子で寝ている猫',
#   'GUMI_AMAE_100.0': '俺のボケを投稿したボケが、殿堂入りしてた',
#   'GUMI_AMAE_10.0': 'この後、彼は見た',
#   'GUMI_AMAE_1.0': '「お前、俺のスタンド狙ってんじゃねーか」',
#   'GUMI_T_3': '降りれないんだけど…',
#   'Neural_Joking_Machine': '「話は聞かせてもらいました。ここがお前の番だ」',
#   'llama': '椅子、壊れちゃったよ',
#   'GUMI_AE': 'お前、俺の靴にガムがついてねえ！',
#   'GUMI_AMAE_1000.0': '「おい、あの女だれだ！」'},
#  {'image_number': 168393,
#   'human': '「王？どこの国の？」',
#   'star': 2,
#   'caption': '眼鏡とスーツを着たアジア人の男は、手を振っている。',
#   'GUMI_AMAE_100.0': '「お前ら、俺の頭の上に乗っけてるやつは、、、」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「ええ、この帽子をかぶったのは、私だ。」',
#   'GUMI_T_3': '「はい、はい、先生の声を発して〜」',
#   'Neural_Joking_Machine': '「ちょっと待って！そのブラジャー返して！」',
#   'llama': 'その男は、眼鏡とスーツを着て手を振っている。',
#   'GUMI_AE': '(こいつ、俺のスタンド…)',
#   'GUMI_AMAE_1000.0': '私は、これで会社に入社しているのだ'},
#  {'image_number': 147211,
#   'human': 'ご覧の通り、我が家にはもう売れるようなものは残っていないんです',
#   'star': 0,
#   'caption': '金閣が水面に映る',
#   'GUMI_AMAE_100.0': '「お前、新入りかい？」',
#   'GUMI_AMAE_10.0': '俺の顔が見たい…',
#   'GUMI_AMAE_1.0': '「おい、誰か塾行く？」「うん、俺、、、、もちょっと。」',
#   'GUMI_T_3': '「この日、人々が起こることは誰も知ってしまいねぇ」「…え？」',
#   'Neural_Joking_Machine': '「お前ら、何でこんな所にイオンができたのか？」',
#   'llama': 'お、金閣寺。',
#   'GUMI_AE': 'この後、この少女を襲った者は、彼の土地の権利書を手のみで追っていた。',
#   'GUMI_AMAE_1000.0': '「お前の攻撃など見切ったー！！」'},
#  {'image_number': 654850,
#   'human': '今日はポイント３倍デーだ',
#   'star': 0,
#   'caption': '干し草を敷いた垣根を馬が走っている',
#   'GUMI_AMAE_100.0': '「お前ら、俺が先に見つけたら、この森の精霊が現れるわ」',
#   'GUMI_AMAE_10.0': '俺の家が',
#   'GUMI_AMAE_1.0': '「「「「「「お、お、お父さん！！！」」」」」」',
#   'GUMI_T_3': 'あ～、あ～、あのぉ～、やっぱり、ちょっと待って',
#   'Neural_Joking_Machine': '「お母さん、僕の顔のブツブツ」「お前、何か食ってるふりしてんな」',
#   'llama': '馬が走り去ったあとに、干し草から、馬の足跡がきれいに残ってる',
#   'GUMI_AE': '「あー、この人、いい感じに焼けましたね」',
#   'GUMI_AMAE_1000.0': '「お前の顔、きもちw」「お前ら人間には勝てないって？所詮トレーニングだ！」'},
#  {'image_number': 751928,
#   'human': '演算超早い',
#   'star': 0,
#   'caption': '銃を持った男の白像',
#   'GUMI_AMAE_100.0': 'この画像のどこかにエロ線が見えるだろう？',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前が俺のスタンドだ！」',
#   'GUMI_T_3': 'ちょっとそこのあなた、指をこっちから見ても完璧じゃないわ',
#   'Neural_Joking_Machine': 'この子が私の頭の上に乗ってるのを聞いたら、本当に試食していた！！',
#   'llama': 'この像が笑うとき、銃声が鳴る。',
#   'GUMI_AE': '「お父さん…」「お母さん！？」',
#   'GUMI_AMAE_1000.0': '「私は、虎になる」と言ったらエスカレートしてこれ、何処までもが異常に増えてた。'},
#  {'image_number': 283262,
#   'human': 'お前に新手の銃を密売してやろう',
#   'star': 0,
#   'caption': 'エビは白い表面に表わされる。',
#   'GUMI_AMAE_100.0': '「お前の席、ねぇから！」',
#   'GUMI_AMAE_10.0': 'お分かり頂けただろうか…',
#   'GUMI_AMAE_1.0': 'お魚くわえたドラ猫が、追いかけてきた',
#   'GUMI_T_3': '「あ、すいませんが別料金です。」',
#   'Neural_Joking_Machine': 'この後スタッフがおいしく頂きました',
#   'llama': '「お絵かきしよう」',
#   'GUMI_AE': 'あ、ごめん。俺の後ろに立つとか、もったいない。',
#   'GUMI_AMAE_1000.0': 'お、お前の手は、、、、あたいも・・・んんんんっ！！！！'},
#  {'image_number': 158354,
#   'human': 'そこまで親しくなくて反応に困る。',
#   'star': 3,
#   'caption': '木の甲板で犬と遊んでいる赤ん坊',
#   'GUMI_AMAE_100.0': '「お前は俺を怒らせた」',
#   'GUMI_AMAE_10.0': '「ああ……」',
#   'GUMI_AMAE_1.0': 'お前の席ねーから！',
#   'GUMI_T_3': 'パパ、ママに怒られるよ。',
#   'Neural_Joking_Machine': '犬が吠えるところを探してる',
#   'llama': '#以下は、タスクを説明する指示と、文脈のある入力の組み合わせです。要求を適切に満たす応答を書きなさい。###指示:入力の文は大喜利のお題です。お題に沿った面白いボケを生成して',
#   'GUMI_AE': '「お前、昨日の相手は、俺の弟だ。」「いや、無理、勘弁してください。」',
#   'GUMI_AMAE_1000.0': '「お母さん、僕がイジメられている最中だから静かにして!!」'},
#  {'image_number': 685201,
#   'human': 'あなたがこのメモを見るということはあなたは家でゴロゴロしていることでしょう。',
#   'star': 0,
#   'caption': 'ノートパソコンに勤める薬局の女性。',
#   'GUMI_AMAE_100.0': '（・・・・・・・・・保留）',
#   'GUMI_AMAE_10.0': '何も無い。',
#   'GUMI_AMAE_1.0': 'お父さん！！お父さんがお母さんになった！',
#   'GUMI_T_3': 'お父さんのお願いします',
#   'Neural_Joking_Machine': 'この人が「私が一番」です',
#   'llama': 'お腹が痛いですか？',
#   'GUMI_AE': '「お前の頭の中に直接！」',
#   'GUMI_AMAE_1000.0': '私の風邪はここから。あなたのそのハートをぶち抜いてね、'},
#  {'image_number': 130959,
#   'human': '犬「お前のバトルボディじゃ俺には勝てない」',
#   'star': 0,
#   'caption': '小さな犬を飼っているタトゥーをまとった男性',
#   'GUMI_AMAE_100.0': '「俺が囮になっている内に早く逃げろ！」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「あ、おかまいなく。」',
#   'GUMI_T_3': 'お父さんお手を拝借！よせ！',
#   'Neural_Joking_Machine': '「お父さん、お母さん、お婆ちゃん、お家に帰って来たわ。」',
#   'llama': '飼い主は小動物です',
#   'GUMI_AE': '「お前はクビだ。」',
#   'GUMI_AMAE_1000.0': '「お前の命はあと三秒だ」『いえいえ、私が払います』'},
#  {'image_number': 156489,
#   'human': 'スタンドがこの程度だった',
#   'star': 0,
#   'caption': '男女の絵',
#   'GUMI_AMAE_100.0': '「え？これ生放送スーツ？」',
#   'GUMI_AMAE_10.0': 'この先は俺が掃除してやる！',
#   'GUMI_AMAE_1.0': '「ちょっと待って、今揺らさないで下さい」',
#   'GUMI_T_3': '左の子がトイレに行った',
#   'Neural_Joking_Machine': '「えーと、産婦人科」で１人とも仲良く話を聞いた',
#   'llama': '男の絵画像に対して一言。',
#   'GUMI_AE': 'あ、お母さんここんくらいの胸だったんだもん',
#   'GUMI_AMAE_1000.0': '俺は今、猛烈にひどいものになる'},
#  {'image_number': 166218,
#   'human': 'うちと結婚するっちゃ！ダーリン！',
#   'star': 0,
#   'caption': '漫画の登場人物が別の男性の上に座っている',
#   'GUMI_AMAE_100.0': '俺のビッグマグナムはこんなんじゃないぞおぉぉぉぉ！！',
#   'GUMI_AMAE_10.0': '何も見えない',
#   'GUMI_AMAE_1.0': '「お前、ヒゲ濃いな。」',
#   'GUMI_T_3': 'お前は絶対に許さん！！！この通り！',
#   'Neural_Joking_Machine': '「この中に、エコ手作り何か混じってます！」って言ったら',
#   'llama': 'この漫画、座る場所がなくて、座ってるだけ。',
#   'GUMI_AE': '(このガキ、自爆する気だ！)',
#   'GUMI_AMAE_1000.0': '俺が地球に向かっていけんな！'},
#  {'image_number': 147969,
#   'human': 'ダメだ〜レモン食べても眠いよう',
#   'star': 0,
#   'caption': '部屋に座っているスーツを着てネクタイをしている男性',
#   'GUMI_AMAE_100.0': '「・・・・・」',
#   'GUMI_AMAE_10.0': 'え！？この家の子？',
#   'GUMI_AMAE_1.0': '「お前の脳みそうまそうだな」',
#   'GUMI_T_3': 'この顔で「お手」とか言いながら、議員を務める。',
#   'Neural_Joking_Machine': 'お前、何で下着盗っ養成木に登ればいいの？',
#   'llama': 'こんにちは、これからお世話になります、ネクタイです。',
#   'GUMI_AE': '「あーー！今から宿題やろうと思ってたのになぁ…でもまぁどうする？もう一度確認しますけど」',
#   'GUMI_AMAE_1000.0': '「お前の母ちゃん、デベソっ！」'},
#  {'image_number': 201511,
#   'human': '孫の握力にはいつも驚かされる･･･',
#   'star': 2,
#   'caption': '抱き合っている年配の男女',
#   'GUMI_AMAE_100.0': '「お前、見込みあり。」',
#   'GUMI_AMAE_10.0': '何も思い出し、何も無い',
#   'GUMI_AMAE_1.0': '「お前の母ちゃん、デベソ」「あら、あなた、頭がハゲてるわ」',
#   'GUMI_T_3': '「お前の年金、すべて聞きたかったのに」',
#   'Neural_Joking_Machine': '俺の中の天使が囁いてくるのは、俺だけだ！！',
#   'llama': 'おっさんと抱き合っていると、何だか切なくなる。',
#   'GUMI_AE': '「お客様、店内での検尿ルームは出口ですので、そちらからお茶は結構です。」',
#   'GUMI_AMAE_1000.0': 'お、おにぎりなんだな。'},
#  {'image_number': 60739,
#   'human': '『待てよ、てめえ!!せめて何で１と１を足したら２になるのかちゃんと説明して帰れ!!気になって寝れねえだろうがッ』',
#   'star': 3,
#   'caption': '口が開いて歯が見えるチンパンジー',
#   'GUMI_AMAE_100.0': '「お前の好きな色は赤ちゃんにしか見えない」などと、愚かな妄想が絶えない',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前の母ちゃん、うまそうだな」',
#   'GUMI_T_3': '「バナナの皮」って言った後に「知らないけど、たぶん喰われる」と思う',
#   'Neural_Joking_Machine': 'おーい、シャンプー変えたよね？',
#   'llama': 'チンパンジー「この歯全部虫歯やで」',
#   'GUMI_AE': 'お前、俺と同じ髪型にしてんだ？',
#   'GUMI_AMAE_1000.0': 'お前の頭にはかなわないみたいだぜ！'},
#  {'image_number': 685876,
#   'human': 'にゃーおにゃーーぉ',
#   'star': 0,
#   'caption': '開けた戸口に立っているハスキードッグ',
#   'GUMI_AMAE_100.0': 'お前もシャワー浴びてから入れよ',
#   'GUMI_AMAE_10.0': '「ああ、私が白黒な」',
#   'GUMI_AMAE_1.0': '「あ、あの、すいません、トイレ貸してください」「はい、すいません。」',
#   'GUMI_T_3': 'あ～、お風呂入っとるで',
#   'Neural_Joking_Machine': 'お、新入りか？',
#   'llama': '開けた戸口に立っているハスキードッグ画像に対して一言。',
#   'GUMI_AE': '「あ、お気遣いなく、これ以上、若かったんですね。」',
#   'GUMI_AMAE_1000.0': '「あ、あの、お構いなく」「あっ、猫です」'},
#  {'image_number': 465896,
#   'human': 'かくれんぼ中にみんな帰ってしまった',
#   'star': 0,
#   'caption': '青いシャツを着て冠をかぶった少女。',
#   'GUMI_AMAE_100.0': '「お前は、、、、、、、、、、、、、、、、、、、、、、、、、、',
#   'GUMI_AMAE_10.0': '「お前は…」',
#   'GUMI_AMAE_1.0': '便座カバーが外れた',
#   'GUMI_T_3': '今日は完ぺき',
#   'Neural_Joking_Machine': 'お前のボケはつまらん',
#   'llama': '少女は今夜、一生に一度の大切な日を迎えている。',
#   'GUMI_AE': '「お前が俺で、俺のボケのセンスには、どんな格好しても全然面白くないな」って、俺って。。',
#   'GUMI_AMAE_1000.0': '「この人痴漢です！」「はい！」'},
#  {'image_number': 257992,
#   'human': 'こうやって犬は鼻から丸かじりが一番美味しく頂けるんですねぇ。',
#   'star': 0,
#   'caption': '白い犬を腕に抱いている年配の女性。',
#   'GUMI_AMAE_100.0': '「お願いです！僕を食べても食べても食べても食べても我慢できません！」',
#   'GUMI_AMAE_10.0': '何か言ってる',
#   'GUMI_AMAE_1.0': 'お父さん、この人が僕のお父さん',
#   'GUMI_T_3': 'おじいさんがご飯をくれない',
#   'Neural_Joking_Machine': 'お前は今まで食ったパンの枚数を覚えているのか？',
#   'llama': '白犬おばあちゃん',
#   'GUMI_AE': '「俺のプリン食ったのお前だろ！」',
#   'GUMI_AMAE_1000.0': '私の彼は、ひょっとして姫が救われたとでも？'},
#  {'image_number': 33001,
#   'human': '「これが仕事なんだから、あっち行ってろや」',
#   'star': 2,
#   'caption': '犬を抱いて床にひざまずく女',
#   'GUMI_AMAE_100.0': '「お父さん、お父さん！」「いや、お前の父さんじゃないから！」',
#   'GUMI_AMAE_10.0': 'お母さん、、、',
#   'GUMI_AMAE_1.0': '「お前、今俺の事見て笑っただろ」',
#   'GUMI_T_3': '「はい、はい、わかったからもう一回やり直してください」',
#   'Neural_Joking_Machine': '「あーっと！一歩前から見ておけ！これが現実だよ。」',
#   'llama': '人間と犬の大きさが同じくらいの写真',
#   'GUMI_AE': '「お前は今まで黙っててごめん」「・・・」',
#   'GUMI_AMAE_1000.0': '「俺の手を借りてほしいんだな」'},
#  {'image_number': 271408,
#   'human': '写す時呼んでって言ったじゃ～ん！！',
#   'star': 0,
#   'caption': '2人の女性が後ろにクマを抱えて水中に立っている',
#   'GUMI_AMAE_100.0': '「あ～ばよ、とっつぁ～ん」「おーっ！」',
#   'GUMI_AMAE_10.0': 'お、お母さん？',
#   'GUMI_AMAE_1.0': '「おい！！お前の母ちゃんデベソ！！」',
#   'GUMI_T_3': 'この後、熊が殺られた',
#   'Neural_Joking_Machine': '「お前がシャケって言ったか？」「んー…鮭の産卵は大変だったね…」',
#   'llama': '2人の女性が後ろにクマを抱えて水中に立っている画像に対して一言。',
#   'GUMI_AE': '「お父さんが知らないメスの匂いしてきた。。」',
#   'GUMI_AMAE_1000.0': 'あ〜あ。般若心経を読み取りにいくか。'},
#  {'image_number': 858345,
#   'human': 'ってこけへんのかーい',
#   'star': 0,
#   'caption': '川の前で三脚跳びをしている男',
#   'GUMI_AMAE_100.0': 'お前ら、俺に逆らうやつは！訓練者だ！',
#   'GUMI_AMAE_10.0': 'この顔に入る',
#   'GUMI_AMAE_1.0': '「お前の母ちゃんでべそ！」「お、お前が手伝えよ！」',
#   'GUMI_T_3': '「あー！この辺りにコンタクト落としましたよ！」「えっ!!」」',
#   'Neural_Joking_Machine': 'あ～ばよ！とっつぁん！',
#   'llama': '三脚跳びって何ですか？',
#   'GUMI_AE': 'この辺で落としたはずなのに。',
#   'GUMI_AMAE_1000.0': '俺の後ろに立つとはな'},
#  {'image_number': 229388,
#   'human': '日頃の反動のせいか急に動かなくなる時がある。',
#   'star': 0,
#   'caption': '丘の上に立っている赤い上着を着た男',
#   'GUMI_AMAE_100.0': '「お前の席ねーから！」',
#   'GUMI_AMAE_10.0': '「おーい、こっちだ。」',
#   'GUMI_AMAE_1.0': '「この子の寿命、すべてなくなった」',
#   'GUMI_T_3': '「僕と一緒に食った奴は誰だよ？」',
#   'Neural_Joking_Machine': '「お前の罪は俺のもの」と言ったのは、お前か！',
#   'llama': '丘の上に立っている赤い上着を着た男画像に対して一言。',
#   'GUMI_AE': '「お、お前…まさか、お前が……誘拐されてる…？」',
#   'GUMI_AMAE_1000.0': 'お母さーん！お父さんがお母さん帰って来たよ！'},
#  {'image_number': 669222,
#   'human': 'イカしてるイカだな。だが、イカなる時もイカす訳にはイカん。',
#   'star': 0,
#   'caption': '男は大きな魚で海で釣りをしている',
#   'GUMI_AMAE_100.0': '「お前ら、俺を見てろ。」',
#   'GUMI_AMAE_10.0': 'ん？この先は俺を越してみろ',
#   'GUMI_AMAE_1.0': '「あ、ごめん。これ全部食べちまった」',
#   'GUMI_T_3': 'イカ釣り漁船に忍び寄るイカ',
#   'Neural_Joking_Machine': '「押すなよ！」って言っただろうがっ！！！',
#   'llama': '男は大きな魚で海で釣りをしている画像に対して一言。',
#   'GUMI_AE': 'お父さんの形見',
#   'GUMI_AMAE_1000.0': 'お父さん、お父さんの子じゃないよ'},
#  {'image_number': 570243,
#   'human': '君にケチャップを語る資格はない！',
#   'star': 0,
#   'caption': '赤い服を着た女性が男の隣に立っている',
#   'GUMI_AMAE_100.0': '「ちょっと待って！今から透明なポールを盗み取り放題だよ！」',
#   'GUMI_AMAE_10.0': '何も無い',
#   'GUMI_AMAE_1.0': 'お前のパンチをかわせるもの、俺の勝ち',
#   'GUMI_T_3': '「お、お客様！お客様！！？」',
#   'Neural_Joking_Machine': 'お前の命を狙う',
#   'llama': '女性の隣にいる男が全裸で、男性器をぶらさげている',
#   'GUMI_AE': '「お、お客様、そちらの方はどうされました？」',
#   'GUMI_AMAE_1000.0': '私、こういう者です。'},
#  {'image_number': 90336,
#   'human': 'やらせろー！！お前、男と知っての事か？？',
#   'star': 1,
#   'caption': '口を開けたライオンが芝生の中を走っている',
#   'GUMI_AMAE_100.0': '「ああ、やっぱり税務署とやら、来年は何年やってられんねや」',
#   'GUMI_AMAE_10.0': 'ん？この後、お母さんが出てきた。',
#   'GUMI_AMAE_1.0': '「ちょっと待て、お前、今、亀の子か？」',
#   'GUMI_T_3': 'あんたはバカァ？',
#   'Neural_Joking_Machine': 'この後、ムツゴロウが攻めて来た！',
#   'llama': '芝刈り機で刈ってもらいたい',
#   'GUMI_AE': 'あーーーーー！！',
#   'GUMI_AMAE_1000.0': 'お前、俺の子だ！！'},
#  {'image_number': 457392,
#   'human': '隣の家の旦那と似てて気まずい',
#   'star': 0,
#   'caption': '赤子を抱いている男性',
#   'GUMI_AMAE_100.0': 'この子は俺が守る',
#   'GUMI_AMAE_10.0': '俺の中の何か',
#   'GUMI_AMAE_1.0': '「お前、今俺の頭にブスって言ったろ！」',
#   'GUMI_T_3': '「お父さんは今日は、お母さんの日なの。」',
#   'Neural_Joking_Machine': 'お互いに親だと思われたくないが、何を言っても「はぁ？」って言ってくる',
#   'llama': '赤子を抱いている男性画像に対して一言。',
#   'GUMI_AE': '俺は、この中に一人称が無いと、誰にも言うなよ',
#   'GUMI_AMAE_1000.0': 'お前の母さんだけは許さん！！'},
#  {'image_number': 106075,
#   'human': '片方がギンギンになる薬もう一方は干しだいこんになっちゃう薬',
#   'star': 0,
#   'caption': '具材が違う紙を2枚重ねたもの。',
#   'GUMI_AMAE_100.0': '「お前は、、、、、、、、、、、ゲホッ・・・」',
#   'GUMI_AMAE_10.0': '「……」',
#   'GUMI_AMAE_1.0': '「あ、これ？石鹸だよ、ええ。」',
#   'GUMI_T_3': '小麦粉を練り込んでから、こんなことになった',
#   'Neural_Joking_Machine': 'これが新しいアートです',
#   'llama': '紙を2枚重ねたもの、ということは……。',
#   'GUMI_AE': 'この後、彼は爆発的なミス鳩と判明した',
#   'GUMI_AMAE_1000.0': '俺を踏んづけたのはお前か？'},
#  {'image_number': 430153,
#   'human': '色んな意味で寒い',
#   'star': 0,
#   'caption': '白黒のフィギュアスケーターが手を握っている',
#   'GUMI_AMAE_100.0': '(……………………………………………………………………………',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前、俺のプリン食べただろ」',
#   'GUMI_T_3': 'ゴキブリを手で叩いてしまった',
#   'Neural_Joking_Machine': 'お前の母ちゃん、俺の母ちゃんでーべそ！',
#   'llama': '白黒のフィギュアスケーターが手を握っている画像に対して一言。',
#   'GUMI_AE': 'お前、鼻毛出てんだろうなぁ。',
#   'GUMI_AMAE_1000.0': 'お父さん…僕がイジメられてると思っていたんですよ'},
#  {'image_number': 643412,
#   'human': '「ヤッフー！また小銭拾っちゃった～」「ぅおっしゃー！やったなぁお前ー！」',
#   'star': 0,
#   'caption': '滝の端に立つ二人の男',
#   'GUMI_AMAE_100.0': 'お前は俺のハートを射抜くのは危険だ！',
#   'GUMI_AMAE_10.0': '「あ、目ぇ…目ぇ…」',
#   'GUMI_AMAE_1.0': '「俺の屍を越えていけ」',
#   'GUMI_T_3': '「おい、押すなよ！絶対押すなよ！！」',
#   'Neural_Joking_Machine': 'お前も道連れだ',
#   'llama': 'お前の顔も洗っておけ',
#   'GUMI_AE': '「お前は何をしているんだ？」「お前が言うんだ」',
#   'GUMI_AMAE_1000.0': '「この人痴漢です！」'},
#  {'image_number': 445637,
#   'human': '男「はぁ！君の飲んだ後はレモンの香りがするな」女「それって、セクハラですね〜ほら、刑法にも載ってますよ」',
#   'star': 0,
#   'caption': '飛行機に座っている男女の写真2枚',
#   'GUMI_AMAE_100.0': '「今日は何しに来たの？」「「「「「チッ！」」」」」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「この子、お母さんにあげるからお父さんを紹介して」',
#   'GUMI_T_3': '左：「ごめんなさい、ごめんなさい。ごめんなさい。」右下：「ごめん、ごめんなさい。」',
#   'Neural_Joking_Machine': '「お前の席ねーから」',
#   'llama': '男が「窓際がよかったのに」と呟いた。',
#   'GUMI_AE': '「お前ら、俺の下半身にモザイクかけろ」',
#   'GUMI_AMAE_1000.0': '「「「「「「「「「「「この人の身長に心の準備すらもついてないんだよ！」」」」」'},
#  {'image_number': 791694,
#   'human': '幽幻道士(*86)',
#   'star': 0,
#   'caption': '教室に飛び込む少女たち',
#   'GUMI_AMAE_100.0': 'この後、スタッフが美味しく頂きました',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': 'お前も頭に乗せとけばさすがに100コンボは無理だな',
#   'GUMI_T_3': '「お前ら先生に教えてー！」と言われた時にはもう遅かった',
#   'Neural_Joking_Machine': '「お前は、お前のこと、俺の子じゃないって言ってんだろ！！」',
#   'llama': '#一言',
#   'GUMI_AE': '「おい、この前俺が見えないだろ！」「俺の後ろに立つんじゃねえ！」',
#   'GUMI_AMAE_1000.0': '「おい、お前の母ちゃん、ピーチをつまみだせ」'},
#  {'image_number': 215947,
#   'human': 'お猿さんたち、ミルクを恵んでくれてありがとな。礼はいらねぇよ。その代わり早くこの浴場作ってくれよ！',
#   'star': 0,
#   'caption': '白い服を着た男が2匹の猿とともにベンチに座っている',
#   'GUMI_AMAE_100.0': '「俺の名前を言ってみろ！」『いや、たしかに言ったんだけどなぁ』',
#   'GUMI_AMAE_10.0': '「・・・」',
#   'GUMI_AMAE_1.0': '「お前、俺の舎弟のシャツ見てて、旧尊くないって言ったやつ誰や」',
#   'GUMI_T_3': 'お前ら全員、お母さんにも見られた事無いのに…',
#   'Neural_Joking_Machine': '「俺が頼んだ松ピカやなくてソース持ってった奴、お前だろ？」',
#   'llama': '1枚目は、猿に「お前の母ちゃん出べそ」とからかわれて激怒する男。',
#   'GUMI_AE': '俺は、俺が守る！',
#   'GUMI_AMAE_1000.0': '「あー！！そこツボったー！！」'},
#  {'image_number': 706501,
#   'human': '頭叩いたら何か出てきて、もう笑うしかない',
#   'star': 0,
#   'caption': 'テーブルに座っている2人の男性',
#   'GUMI_AMAE_100.0': '「あ～ばよ、とっつぁ～ん」「お、お前が悪いんか～い」',
#   'GUMI_AMAE_10.0': '何も思い出し、何も無い',
#   'GUMI_AMAE_1.0': '「あー、これ、手袋の柄のセンスだわ。」',
#   'GUMI_T_3': '「お前、俺の女の子じゃね?」',
#   'Neural_Joking_Machine': 'あ～あ～、あ～あ～、果てしない～♪',
#   'llama': '#入力画像に対して一言',
#   'GUMI_AE': 'この後、この絵画を立体から見た',
#   'GUMI_AMAE_1000.0': '「俺のプリン食べたのお前か？」「いや、俺だ」'},
#  {'image_number': 756092,
#   'human': '今日うちに寄ってく？今日は誰もいないの♡',
#   'star': 1,
#   'caption': '長いオレンジ色の髪と青いシャツを着た若い女性',
#   'GUMI_AMAE_100.0': '「この辺が一番乾燥れてるのね。」「えっ、、、」',
#   'GUMI_AMAE_10.0': '俺の家の中で何か見えた',
#   'GUMI_AMAE_1.0': 'この子の名前を言ってみ？',
#   'GUMI_T_3': '俺の名前は「名前」だっけ☆',
#   'Neural_Joking_Machine': 'この顔にピンッ！',
#   'llama': '彼女は僕にしか見えない',
#   'GUMI_AE': '(この人、俺の胸にシリコン入れてるな‥)',
#   'GUMI_AMAE_1000.0': '「お父さん、お母さん、、、、」'},
#  {'image_number': 94190,
#   'human': 'こちょこちょ、笑えよ、こちょこちょ',
#   'star': 1,
#   'caption': '草むらでライオンを飼っている男。',
#   'GUMI_AMAE_100.0': '「お前ら、俺が悪かったって！」',
#   'GUMI_AMAE_10.0': 'お、お母さん？',
#   'GUMI_AMAE_1.0': 'このポーズをすると、たまたま見えるようになった',
#   'GUMI_T_3': 'はいはい！はいはい！はい！はい！はいはい！はい！はい！はい！わかりました！',
#   'Neural_Joking_Machine': 'あ〜あ〜あ〜〜〜あ〜あ〜あ〜！',
#   'llama': 'ライオンは、草を食べている。',
#   'GUMI_AE': '俺は人間を辞めるぞっ！',
#   'GUMI_AMAE_1000.0': 'ちょっと男子ぃ〜！！！真面目にやってよぉぉ！'},
#  {'image_number': 30958,
#   'human': '注文ミスであり余ってるんで、すし５００円で買ってくれませんかぁ？',
#   'star': 1,
#   'caption': 'オレンジ色のシャツを着た漫画のキャラクター',
#   'GUMI_AMAE_100.0': '「お前、うまそうだな」',
#   'GUMI_AMAE_10.0': '何も言えねぇ',
#   'GUMI_AMAE_1.0': '「私の事は嫌いになっても、他のメンバーは嫌いになって下さい。」',
#   'GUMI_T_3': '「のびた！」',
#   'Neural_Joking_Machine': 'あーあ、今日もかっちゃ寝癖に間に合わなかった',
#   'llama': 'オレンジ色のシャツを着た漫画のキャラクター画像に対して一言。',
#   'GUMI_AE': '「あ〜、そこそこ！そこ痒い！」',
#   'GUMI_AMAE_1000.0': 'お母さんの乳を飲ませたら、こんなんになった'},
#  {'image_number': 466966,
#   'human': '囮はこの辺で良し…っと。',
#   'star': 0,
#   'caption': '川の前に立っている漫画のキャラクター',
#   'GUMI_AMAE_100.0': '俺の手相はどうですか！',
#   'GUMI_AMAE_10.0': 'ん？この中に入ってるね。',
#   'GUMI_AMAE_1.0': '「この後、彼は病院に連れていかれ、新婦の入場です」',
#   'GUMI_T_3': '飛べない豚はただの豚だあああ！',
#   'Neural_Joking_Machine': '「あ、すみません。これ盲腸なんで、手伝ってもらっていいんですか？」',
#   'llama': '「この川は流れが早い」',
#   'GUMI_AE': 'お前のボケはつまらん。。。',
#   'GUMI_AMAE_1000.0': 'お前、どこ中だよ？'},
#  {'image_number': 634136,
#   'human': 'めんどくさい先輩に見つかった',
#   'star': 7430,
#   'caption': '口を開けた黒いレスラー。',
#   'GUMI_AMAE_100.0': 'お前の母ちゃんでーべそ！',
#   'GUMI_AMAE_10.0': '…………',
#   'GUMI_AMAE_1.0': '「シンプルに口が臭い」',
#   'GUMI_T_3': 'お前の母ちゃんで〜ベ〜ベ〜♪',
#   'Neural_Joking_Machine': '俺が喋るときだけこの顔',
#   'llama': '口を開けた黒いレスラー。',
#   'GUMI_AE': 'このボケが投稿出来るとプーが言いたい',
#   'GUMI_AMAE_1000.0': 'お前、俺の事好きだろ？'},
#  {'image_number': 829595,
#   'human': 'いやしが隙間からこんにちは',
#   'star': 235,
#   'caption': '椅子に座って身振りをする少女',
#   'GUMI_AMAE_100.0': '俺のボケ一覧を見てこの笑顔',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': 'えー！今日一日なにゃったか知らないの？',
#   'GUMI_T_3': '「私のボケに☆を付けるくらいは☆付けてね！」「あ、はい、ごめんなさい。」',
#   'Neural_Joking_Machine': 'お願いします！！！！',
#   'llama': '「大喜利のお題、少女画像に対して一言」と書いてください。',
#   'GUMI_AE': 'この後、お供え物が積み上がった。',
#   'GUMI_AMAE_1000.0': 'お前、俺の事見えてる？'},
#  {'image_number': 278348,
#   'human': '悩みですか？…ん〜悩みと言えば前しか見えない事ですかね',
#   'star': 329,
#   'caption': '大きなアフロがロッカーに座っている男性',
#   'GUMI_AMAE_100.0': '「お前の席ねぇから！」',
#   'GUMI_AMAE_10.0': 'この子',
#   'GUMI_AMAE_1.0': '「あ、おひょく…」',
#   'GUMI_T_3': '髪の毛の量が異常',
#   'Neural_Joking_Machine': '「この中に一人妹がいる」と言われ、ついさっきまで騒がしかった',
#   'llama': 'ロッカーに座るアフロ',
#   'GUMI_AE': '「お前に八百長が必要な事はない。」',
#   'GUMI_AMAE_1000.0': 'え？これ、私の家の前に住んでいた虫？'},
#  {'image_number': 171773,
#   'human': '今日も世話になんで（笑）',
#   'star': 1218,
#   'caption': '緑色のズッキーニを掲げている女性。',
#   'GUMI_AMAE_100.0': '「今日は何をすればいいんだ？」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「はい、じゃあ次は、お前の番よ」',
#   'GUMI_T_3': 'ゴーヤのゴーヤ',
#   'Neural_Joking_Machine': '「お前が俺のプリンをやろう！！」',
#   'llama': '大喜利のお題:緑色のズッキーニを掲げている女性。画像に対して一言。###指示:入力の文は大喜利のお題です。お題に沿った面白いボケを生成してください。###入力:',
#   'GUMI_AE': 'あ、お父さん、、、、',
#   'GUMI_AMAE_1000.0': 'お母さん！僕は元気な男の子ですよ！'},
#  {'image_number': 201511,
#   'human': '年金支給日',
#   'star': 4579,
#   'caption': '抱き合っている年配の男女',
#   'GUMI_AMAE_100.0': '「お前の母ちゃんデベソー」',
#   'GUMI_AMAE_10.0': 'この顔に合う',
#   'GUMI_AMAE_1.0': '「あら、お父さん、離婚したんだね」',
#   'GUMI_T_3': 'おじいちゃんの家は孫が高いわね',
#   'Neural_Joking_Machine': '「お父さんこいつを土台のタイルにしておいて下さい」',
#   'llama': 'あ、抱き合ってます、お母さん。',
#   'GUMI_AE': '「この子、将来結婚します！」って、言ったら、こんな感じなもんです。',
#   'GUMI_AMAE_1000.0': '「この辺りで眼鏡落ちてませんでしたか？」「いや、私の手じゃ足りないんじゃないですか？」'},
#  {'image_number': 465896,
#   'human': 'テスト前日、１０分だけ仮眠をとってから勉強しようと思ってたら朝になってた。',
#   'star': 757,
#   'caption': '青いシャツを着て冠をかぶった少女。',
#   'GUMI_AMAE_100.0': '「お前の介護が終わるまで我慢しろよ」',
#   'GUMI_AMAE_10.0': '「あ、お母さん。」',
#   'GUMI_AMAE_1.0': 'お前の席ねぇーから！',
#   'GUMI_T_3': '今日は私の家で燃やしちゃおっかな',
#   'Neural_Joking_Machine': 'あ、ちょっと待って、くしゃみでそう。',
#   'llama': '青いシャツを着て冠をかぶった少女。画像に対して一言。',
#   'GUMI_AE': 'この人誰？',
#   'GUMI_AMAE_1000.0': 'お父さんにロケットのデザインが斬新'},
#  {'image_number': 90336,
#   'human': 'どうやっても崖から落ちない',
#   'star': 163,
#   'caption': '口を開けたライオンが芝生の中を走っている',
#   'GUMI_AMAE_100.0': '「お前は、俺の子じゃない」',
#   'GUMI_AMAE_10.0': 'んんんんんんんんん！',
#   'GUMI_AMAE_1.0': '「おい、あいつ、俺の背中を橋として呼んだんだ」',
#   'GUMI_T_3': 'しーずかーちゃん！？',
#   'Neural_Joking_Machine': '「おいっ！俺が崖の上に落ちてるのは、俺の方が強い！」',
#   'llama': '芝生が口に入った。',
#   'GUMI_AE': '「俺、こんな所に隠れたなんて…」「あ～！また明日学校で習ったわ～！」',
#   'GUMI_AMAE_1000.0': '「お嬢さん、お茶お持ち」'},
#  {'image_number': 215947,
#   'human': '「あのな、むかしむかしあるところで俺とお前達の親父で鬼とかいう怪物倒したんじゃぞ」『へえ』',
#   'star': 111,
#   'caption': '白い服を着た男が2匹の猿とともにベンチに座っている',
#   'GUMI_AMAE_100.0': '「俺の事は構わず先にいけ！」',
#   'GUMI_AMAE_10.0': 'ん？この中に入って入った？',
#   'GUMI_AMAE_1.0': '「あ、すいません。もうちょっと右でお願いします。」',
#   'GUMI_T_3': '「お前ら何で俺が見えんの？」「お前にはわかるんだ。」',
#   'Neural_Joking_Machine': 'この子を解き放て！',
#   'llama': '男「白い猿には気を付けろ」',
#   'GUMI_AE': 'あ、ちょっと待って、今から空飛びます',
#   'GUMI_AMAE_1000.0': '「俺たち、何かやだ～い！」'},
#  {'image_number': 422007,
#   'human': '…さてとどうやって降りようかしら',
#   'star': 119,
#   'caption': 'ポケットに手を入れて岩に腰掛けている女性',
#   'GUMI_AMAE_100.0': '「お前の敗けだ、お前の罪を数えろ」',
#   'GUMI_AMAE_10.0': '何も無い。',
#   'GUMI_AMAE_1.0': '「お前、雪に乗ってサバンナ行くって言ってたやんか」',
#   'GUMI_T_3': 'この角度から撮れた！！',
#   'Neural_Joking_Machine': 'この先、ちょっと太もも真っ青！！',
#   'llama': 'この岩は俺のものだ',
#   'GUMI_AE': 'この写真で炎上できる',
#   'GUMI_AMAE_1000.0': '「この辺にヌーディストビーチがある？」'},
#  {'image_number': 642935,
#   'human': '踏んでも関係ぇねぇー！踏んでも関係ぇねぇー！',
#   'star': 455,
#   'caption': '銀のスーツを着た男が走っている',
#   'GUMI_AMAE_100.0': '「お前は俺を怒らせた」',
#   'GUMI_AMAE_10.0': '俺の家に火を着けた',
#   'GUMI_AMAE_1.0': '「もうちょっとで女風呂見えそう」',
#   'GUMI_T_3': '怪獣が現れた！！',
#   'Neural_Joking_Machine': '「あ〜…あーあ、暇だな…」',
#   'llama': '銀のスーツを着た男が走っている画像に対して一言。',
#   'GUMI_AE': 'お前の母ちゃんで〜べそ！',
#   'GUMI_AMAE_1000.0': '「「「お控えなっ！！」」」'},
#  {'image_number': 79811,
#   'human': '／カチカチッ＼／ホッ＼',
#   'star': 718,
#   'caption': '赤い上着を着た男が微笑んでいる',
#   'GUMI_AMAE_100.0': '「この人は、何が知りたい？」の質問に対して、無言の答え',
#   'GUMI_AMAE_10.0': '「…」',
#   'GUMI_AMAE_1.0': '「お前、今、屁こいたやろ？」',
#   'GUMI_T_3': '「お前、俺のスタンド知らなーい？」',
#   'Neural_Joking_Machine': '「あ、ごめん」「お前が悪い」',
#   'llama': '上着が裏表逆だ',
#   'GUMI_AE': 'あ、もしもし？俺の家、燃えてる？',
#   'GUMI_AMAE_1000.0': 'お前の母ちゃんでーべそ！'},
#  {'image_number': 640703,
#   'human': 'この表紙の頃はまだ読んでたなー。ジャンプ。',
#   'star': 153,
#   'caption': '長髪の男性2人の絵画',
#   'GUMI_AMAE_100.0': 'この中に１人妹がいる！！',
#   'GUMI_AMAE_10.0': '(やべ、気に入った。)',
#   'GUMI_AMAE_1.0': '「おいおい、俺の頭に蚊がとまってんだろうか？」',
#   'GUMI_T_3': '「これは私の乳首です！」「いえ私の方こそ」',
#   'Neural_Joking_Machine': '「「「「お前は立てなくなっただろうか」」」」」',
#   'llama': '男性2人の長髪が絡み合い、もつれ合い、こんがらがっている。',
#   'GUMI_AE': '「お前は虎の血を引いている前に逃げろ！」',
#   'GUMI_AMAE_1000.0': '「あ、ちょっと待って。いま、体温計かけないでくるわ。」'},
#  {'image_number': 552246,
#   'human': '好きな娘に｢クリスマス暇？｣と聞かれたので思い切り暇です！と答えたらシフト代わってと言われた。',
#   'star': 683,
#   'caption': '長髪にスーツ姿の漫画のキャラクター。',
#   'GUMI_AMAE_100.0': '「ああ～！！！！！！！！！！！！」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「あ～あ～、もう給食食べると、お菓子買ってくれないか？」',
# ...
#   'llama': '犬と二人連れの漫画のキャラクター画像に対して一言。',
#   'GUMI_AE': '「お前の頭をお食べ」「…」',
#   'GUMI_AMAE_1000.0': '「お前が落としたのはこの斧か？」「あ、間違えました、すいませんでした」'},
#  {'image_number': 644634,
#   'human': 'どこからでも3ポイントシュートを打ってくる',
#   'star': 183,
#   'caption': '手のひらでソファに横たわっている猫',
#   'GUMI_AMAE_100.0': '「お前は俺に構わず先に行け！」',
#   'GUMI_AMAE_10.0': '何も見えない',
#   'GUMI_AMAE_1.0': '猫「お前、俺のペディグリーチャム食っただろ！？」',
#   'GUMI_T_3': 'にゃんて日だ！',
#   'Neural_Joking_Machine': '「おい、それ、うちの子ちゃうん？」',
#   'llama': 'ソファで横たわる猫の画像に対して、面白い一言を返してください。',
#   'GUMI_AE': '「俺、この戦争が終わったら結婚するんだ・・・」',
#   'GUMI_AMAE_1000.0': '猫に干支を譲ってやろうと思ったがどうやら裏切りそうだという思うと戸惑う'},
#  {'image_number': 441797,
#   'human': '初エッチしたことを言いたくて仕方ない',
#   'star': 271,
#   'caption': '両腕を組んで髪を伸ばした状態の力士。',
#   'GUMI_AMAE_100.0': '「あ～あ、また、ずるむけ・・・」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前、眉毛太いな」',
#   'GUMI_T_3': 'え？今？！',
#   'Neural_Joking_Machine': '俺は今まで生きてきた中で一番幸せ',
#   'llama': '両腕を組んで髪を伸ばした状態の力士。画像に対して一言。',
#   'GUMI_AE': '俺のプリン食ったのお前か！',
#   'GUMI_AMAE_1000.0': 'この人痴漢です!!!'},
#  {'image_number': 533462,
#   'human': '生き別れの兄を探してるんですが、手がかりが全く無いんですよね…',
#   'star': 9740,
#   'caption': '魚をかぶった帽子をかぶった男性',
#   'GUMI_AMAE_100.0': '「この子は、ふたなり」・・・',
#   'GUMI_AMAE_10.0': '俺の顔の半分は',
#   'GUMI_AMAE_1.0': '「俺の方が年上だろ？」',
#   'GUMI_T_3': 'さかな君の家が火事で、家に帰ったら空と戯れ、彼女が待ち合わせした',
#   'Neural_Joking_Machine': 'この人、さっきからずっと私の頭の中に居た。',
#   'llama': '魚をかぶった帽子をかぶった男性画像に対して一言。',
#   'GUMI_AE': '「この子の名前教えて下さい。」',
#   'GUMI_AMAE_1000.0': '「お前、どこ中だよ！？」「いや、お前、お前こそ！」'},
#  {'image_number': 223930,
#   'human': '滑り込んできた冷凍マグロを水鉄砲のピュッピュで解凍している',
#   'star': 139,
#   'caption': '部屋に銃を持ったスーツを着た男。',
#   'GUMI_AMAE_100.0': 'お前は俺のスタンドが見えているのか？',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前、俺のプリン食いやがったな」',
#   'GUMI_T_3': '「お前は俺のプリンを食ったのは、俺じゃない！」',
#   'Neural_Joking_Machine': '「お前のパソコン見失ったのか」「それはこれくらいのサイズですよ！」',
#   'llama': '部屋に銃を持ったスーツを着た男。画像に対して一言。',
#   'GUMI_AE': 'このくらいの大きさまでどれか一つや付けますか？',
#   'GUMI_AMAE_1000.0': '「お前は俺を抱きたい。この世にいないだろう、おとなしさ」'},
#  {'image_number': 565543,
#   'human': 'スリーボール！！',
#   'star': 1411,
#   'caption': '野球バットを振り回す少年のぼかし写真',
#   'GUMI_AMAE_100.0': '「あ、ごめん。待った？」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': 'ボールがヒットエンドランのサインを出してきたので、ピッチャーが球投投げた瞬間',
#   'GUMI_T_3': 'バットの芯をフルスイング',
#   'Neural_Joking_Machine': 'この後、衝撃を受け駆け巡った少年',
#   'llama': '振り回す少年のぼけ',
#   'GUMI_AE': '玉を打てて、腰が砕ける、関取',
#   'GUMI_AMAE_1000.0': '「お前の攻撃など見切った。」'},
#  {'image_number': 809375,
#   'human': 'サザエでございま〜す♪',
#   'star': 205,
#   'caption': '男性の顔は、カラフルな絵具で描かれている。',
#   'GUMI_AMAE_100.0': '「あ～、あ～、あ～あ～果てしない～♪」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '俺は人間をやめるぞ！ジョジョーッ！！！',
#   'GUMI_T_3': '「お前が落としたのはこの黒板か？それともノートに書いたのか？」',
#   'Neural_Joking_Machine': 'お前が俺の頭を触った経験を全部平然と言ってくるぞ！',
#   'llama': 'この絵具、乾いたら取れるんすよ',
#   'GUMI_AE': '俺、今日シフト入ってなかったよ',
#   'GUMI_AMAE_1000.0': '「あ、あの～、そろそろ代金を支払います」'},
#  {'image_number': 281343,
#   'human': 'あげないよ',
#   'star': 658,
#   'caption': '古い建物のポーチに座っている狐の子2匹',
#   'GUMI_AMAE_100.0': '「お前が俺で、俺がお前で？」',
#   'GUMI_AMAE_10.0': '‖‖‖‖‖‖‖‖‖',
#   'GUMI_AMAE_1.0': '「あー、これ、お前のマウスじゃねーか」',
#   'GUMI_T_3': 'きつねの威を借るきつね',
#   'Neural_Joking_Machine': 'お前が落としたオレンジの木、銀かなんか？',
#   'llama': '「おっさん臭い」',
#   'GUMI_AE': '「お父さん、お父さんがお母さんにこんくらいでって言ってたわよ。」',
#   'GUMI_AMAE_1000.0': '「おいおい、俺は昔からゴリラって言ったの、お前だろ？」'},
#  {'image_number': 747190,
#   'human': '先輩ちぃーーっす！',
#   'star': 14033,
#   'caption': '二本の矢がついた道標',
#   'GUMI_AMAE_100.0': '「俺が悪かった！」と言った友人が、どうやら俺を吸収してしまい、無言で見つかった',
#   'GUMI_AMAE_10.0': 'え？この後のトイレ',
#   'GUMI_AMAE_1.0': '「お前、今から、俺の後ろに並んでる奴がいるって」',
#   'GUMI_T_3': 'お尻に敷かれる',
#   'Neural_Joking_Machine': 'この中に、ウツボが群がる幼稚園のプールに落ちてくる',
#   'llama': '『道標です』',
#   'GUMI_AE': 'このくらいでいっぱい入る冷蔵庫ください',
#   'GUMI_AMAE_1000.0': 'お前は俺を怒らせた'},
#  {'image_number': 228650,
#   'human': '葬式で思いだし笑いを我慢',
#   'star': 638,
#   'caption': '悲しそうな顔と笑顔の赤ん坊',
#   'GUMI_AMAE_100.0': 'くやしいです！',
#   'GUMI_AMAE_10.0': '🟥���',
#   'GUMI_AMAE_1.0': '悔しいです！',
#   'GUMI_T_3': 'くやしいです！',
#   'Neural_Joking_Machine': 'お母さんがオムツ変えてやったんだよ',
#   'llama': '赤ん坊に「この赤ん坊は、この赤ん坊は、生まれてくる世界を間違えた」と言う。',
#   'GUMI_AE': 'お父さんったら！こんなん出てきてよ！',
#   'GUMI_AMAE_1000.0': 'くやしいです！！！'},
#  {'image_number': 228284,
#   'human': '「君のギャラ、少し色つけといたから」「あざーーーす！」',
#   'star': 450,
#   'caption': 'チンパンジーと遊んでいる少年',
#   'GUMI_AMAE_100.0': '「いいか！俺が言いたいのはクッパパボイパでもねえよデブ！」',
#   'GUMI_AMAE_10.0': 'お気に入りの、、、',
#   'GUMI_AMAE_1.0': '「お前の母ちゃん、デベソー！」「えっ？」「「「えっ」」」',
#   'GUMI_T_3': '「俺たち兄弟の中で何匹って言うのかー？」',
#   'Neural_Joking_Machine': '「この人が本当のお母さんじゃないのー！！」',
#   'llama': '少年「チンパンジーをチンパンジーと呼ぶのはやめよう」',
#   'GUMI_AE': 'あー、なるほどね〜。あ、やっぱり俺たちって、哺乳類だったらな。',
#   'GUMI_AMAE_1000.0': '「俺のプリン食べたんは」「はぁーー！？」'},
#  {'image_number': 614111,
#   'human': '割りと簡単に殺れたな...',
#   'star': 318,
#   'caption': '帽子とスーツ姿の男性の漫画の画像',
#   'GUMI_AMAE_100.0': 'この中に一人妊婦がいるんだ',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': 'お前、鼻毛出てるぞ',
#   'GUMI_T_3': '次元を超えたにらめっこで開始からずっと緊張してる',
#   'Neural_Joking_Machine': '「あ～！またあの子の頭を追いかけてる～！」',
#   'llama': 'この画像にセリフを付けるなら、どんなセリフがいい？',
#   'GUMI_AE': '「ええ、そうですね。この状態から入れる保険は一切までである」',
#   'GUMI_AMAE_1000.0': '今日は、この公園で働くことになりました！'},
#  {'image_number': 48991,
#   'human': '全然来ないのでボタン連打してたらいっぱい来た',
#   'star': 1226,
#   'caption': 'テーブルのまわりに座っている男性の集団',
#   'GUMI_AMAE_100.0': '「お前の母ちゃんで、べ、そとな」',
#   'GUMI_AMAE_10.0': '‖‖‖‖‖',
#   'GUMI_AMAE_1.0': '「お前、俺のプリン食っただろ！」',
#   'GUMI_T_3': '「俺の事、思い付いていてくれ！」「俺達は何も見ていないんだよ」',
#   'Neural_Joking_Machine': 'お前らの募金、待ってるぜ！',
#   'llama': 'テーブルのまわりに座っている男性の集団画像に対して一言。',
#   'GUMI_AE': '「この子が私の子じゃないんです、あなたは貴方を見ています」',
#   'GUMI_AMAE_1000.0': 'お、おい、俺のボケに星を押してやろうか！！'},
#  {'image_number': 256865,
#   'human': '去勢される夢を見てうなされている',
#   'star': 251,
#   'caption': 'ハスキー・ドッグで背中を横たわっている男',
#   'GUMI_AMAE_100.0': '「お前の母ちゃんの悪口はそこまでだ！」',
#   'GUMI_AMAE_10.0': '「この中に何が入っているのか分かった！」',
#   'GUMI_AMAE_1.0': '「お前、俺の尻尾の色を見ろ！」',
#   'GUMI_T_3': '(よし、これで完璧な擬人化してみよう)',
#   'Neural_Joking_Machine': '「お前は見んといて」「ん」',
#   'llama': '大喜利のお題:ハスキー・ドッグで背中を横たわっている男画像に対して一言。↓ハスキー・ドッグで背中を横たわっている男画像に対して一言。↓ハスキー・ドッグは「背中を横',
#   'GUMI_AE': '「あー、やっぱり私が悪いんですが、この辺りはもう結構です。」',
#   'GUMI_AMAE_1000.0': 'あ、ちょっとカメラ止めて。'},
#  {'image_number': 854542,
#   'human': 'ブラ…ル…人…聞こ…ますかー…',
#   'star': 122,
#   'caption': '岩を眺めて地面にひざまずく男',
#   'GUMI_AMAE_100.0': '「お前が落としたのはこの金のハンバーガーは？」「「「「「「「いらっしゃいませ！」」」',
#   'GUMI_AMAE_10.0': '………',
#   'GUMI_AMAE_1.0': '「俺、昨日の忘年会でウケなかった俺の先輩！」',
#   'GUMI_T_3': 'この辺に落としたと思う？これ全部落としたの？',
#   'Neural_Joking_Machine': '「俺、やっぱり象さんの方が良かったんだよなぁ…」',
#   'llama': '男は岩に恋をしている。',
#   'GUMI_AE': '「俺、お前らの募金待ってるぜ」の巻',
#   'GUMI_AMAE_1000.0': '俺のスタンドは暗殺シマウマだあぁぁぁ！！！'},
#  {'image_number': 383653,
#   'human': '修羅場ニアファミリー',
#   'star': 751,
#   'caption': '人形の家の中にぬいぐるみを入れた人形の家',
#   'GUMI_AMAE_100.0': '修羅場ニアファミリー',
#   'GUMI_AMAE_10.0': 'おおー！',
#   'GUMI_AMAE_1.0': '「お父さん、お母さん…」「…」「うん……」',
#   'GUMI_T_3': '修羅場ニアファミリー',
#   'Neural_Joking_Machine': '修羅場ニアファミリー',
#   'llama': 'このぬいぐるみは、人形の家に引っ越してきた人形の家に引っ越してきた人形の家です。',
#   'GUMI_AE': 'この拳のシンクはブルーだけが見事である',
#   'GUMI_AMAE_1000.0': '修羅場ニアファミリー'},
#  {'image_number': 98418,
#   'human': '皆でふざけあっていたら目に指が入り空気が一変した',
#   'star': 199,
#   'caption': '廊下で子供たちと踊る女性',
#   'GUMI_AMAE_100.0': '「お前の母ちゃんでべそ～」',
#   'GUMI_AMAE_10.0': 'あ、この先は通れない',
#   'GUMI_AMAE_1.0': '「お前の席ねーから！」',
#   'GUMI_T_3': 'え、ええ！？',
#   'Neural_Joking_Machine': 'この子が私を見た最後の最後に、ほんのちょっといい雰囲気',
#   'llama': '大喜利で言うと何点？',
#   'GUMI_AE': '「この中に一人妹がいる！」',
#   'GUMI_AMAE_1000.0': '「お母さん！お風呂入ってたわよ！」「はーい、先生」'},
#  {'image_number': 376971,
#   'human': 'ごめんな、ちょっとエサわけてくれ',
#   'star': 362,
#   'caption': '公園でハトに餌をやっている女性',
#   'GUMI_AMAE_100.0': '「お前の力はその程度か？」',
#   'GUMI_AMAE_10.0': '「…………」',
#   'GUMI_AMAE_1.0': '「お、俺の屍を越えていけ…」',
#   'GUMI_T_3': 'この子が主役の座を奪うとは誰も思うまい',
#   'Neural_Joking_Machine': 'お前も俺の名前は「猫」だ',
#   'llama': 'ハトを「カゴに閉じ込めて、羽根をもいで、生肉を食わせて太らせて」「カゴごと売ってる」',
#   'GUMI_AE': 'お前の家、傾いてません！！',
#   'GUMI_AMAE_1000.0': 'あ〜そこそこ、そこが痒いの？'},
#  {'image_number': 827585,
#   'human': '食べていい？',
#   'star': 4470,
#   'caption': '犬がドッグフードを食べている',
#   'GUMI_AMAE_100.0': 'お前の頭はくるくるーこだまー',
#   'GUMI_AMAE_10.0': '(……………………………………………………………………………',
#   'GUMI_AMAE_1.0': '「お前、何が望みだ？」「堅いわっ！」',
#   'GUMI_T_3': '「…あっ、ごめん、ごめん。俺も食べれない。」',
#   'Neural_Joking_Machine': '「お前、何でウチの庭で飯食ってんだよ。」「・・・・。」',
#   'llama': '犬がドッグフードを食べている画像に対して一言。',
#   'GUMI_AE': '「この子、お尻触ったでしょ。」',
#   'GUMI_AMAE_1000.0': 'ちょっとぉー！！'},
#  {'image_number': 534275,
#   'human': '庭用ルンバ',
#   'star': 151,
#   'caption': '草食の草にひざまずく男',
#   'GUMI_AMAE_100.0': '「お前ら、俺がデブだなんて、、、」',
#   'GUMI_AMAE_10.0': 'この中に………………………',
#   'GUMI_AMAE_1.0': '「お願い、天然で！ニンジン食って！」',
#   'GUMI_T_3': '「あ、大丈夫ですよ、今は馬になりませんから…」',
#   'Neural_Joking_Machine': 'この人チカンです！と思ってました。',
#   'llama': '「おい、草食ってんじゃねぇぞ」',
#   'GUMI_AE': '「お母さん、今日は何で裸で公園に連れてきたんだってよ」',
#   'GUMI_AMAE_1000.0': '「この土地のシールを貼る度に開発された」'},
#  {'image_number': 718536,
#   'human': 'そろそろ、おじいちゃんを散歩に連れて行く時間。',
#   'star': 3162,
#   'caption': '道端を歩く犬',
#   'GUMI_AMAE_100.0': '「お前は今、自分が落したやつを見つけるまで帰れないんだよ」',
#   'GUMI_AMAE_10.0': 'って思ってたのと違う',
#   'GUMI_AMAE_1.0': '「え、お前の子じゃなかったの？」',
#   'GUMI_T_3': 'あーあ！これ？飼い主さんより庶民。',
#   'Neural_Joking_Machine': 'この床、地面にめり込んだ水が出てくるはず！！',
#   'llama': '犬の真似をして、全力疾走で横断歩道を渡った。',
#   'GUMI_AE': '「この中にお医者様はいらっしゃいませんかー！」',
#   'GUMI_AMAE_1000.0': '「あ、ちょっとタイム。」'},
#  {'image_number': 254575,
#   'human': 'そんな大きい声出したってお母さんぜんぜん恐ないわ',
#   'star': 751,
#   'caption': '2匹の犬が口を開けて土の中に立っている。',
#   'GUMI_AMAE_100.0': '「お前、俺のプリン食っただろ！」「いや、お前の頭ん中やで」',
#   'GUMI_AMAE_10.0': 'この後、目を開けて下さい。',
#   'GUMI_AMAE_1.0': '「お前の母ちゃんデベソ！」',
#   'GUMI_T_3': 'お前に教えるのは今日から中学の友達だ',
#   'Neural_Joking_Machine': 'お前の小屋は、ええ？',
#   'llama': '犬は「あ」を、土は「ん」を表している。つまり「あうん」と言いたい。',
#   'GUMI_AE': '「この人、お前に夢中で有名な占い師だ」「お前もな。」',
#   'GUMI_AMAE_1000.0': 'お母さん、今日は休みたい日って約束したじゃない'},
#  {'image_number': 470527,
#   'human': 'さぁ、次は自転車でそのあとマラソンよ。',
#   'star': 824,
#   'caption': '浜辺を歩く二人の女と赤ん坊',
#   'GUMI_AMAE_100.0': '「お前の母ちゃんデベソー」',
#   'GUMI_AMAE_10.0': 'この先は何を出す',
#   'GUMI_AMAE_1.0': '「お前が歌うんかい！！」',
#   'GUMI_T_3': 'この子は、あなたが選んだ自殺を見抜いていっちゃうわよ！',
#   'Neural_Joking_Machine': '「お父さんが帰ってくる前に逃げて！」',
#   'llama': '浜辺を歩く二人の女と赤ん坊画像に対して一言。',
#   'GUMI_AE': '「お前、この前の募金、待ったよ。」『・・・・・・・』',
#   'GUMI_AMAE_1000.0': '「お、お父さん…？」'},
#  {'image_number': 210423,
#   'human': '伝説のスリ',
#   'star': 276,
#   'caption': '廊下を歩く人々',
#   'GUMI_AMAE_100.0': '「この店は初めてかい？」といわれ複雑な心境',
#   'GUMI_AMAE_10.0': '俺の家の猫',
#   'GUMI_AMAE_1.0': '「あ～、やっぱり牛乳は飲めませんね！」',
#   'GUMI_T_3': '「私は中にチューっと注入！」',
#   'Neural_Joking_Machine': 'あ、あの、ちょっと前に来て、後でまとめて見たんで。',
#   'llama': 'あなたは廊下を歩く人々画像に対して一言。',
#   'GUMI_AE': '「あ～！！！おばけ～！！！」',
#   'GUMI_AMAE_1000.0': '私は、あなたの味方だから。'},
#  {'image_number': 412739,
#   'human': 'だいぶつまってる',
#   'star': 3044,
#   'caption': '仏頭が多数並ぶ石垣',
#   'GUMI_AMAE_100.0': '「お前の席ねぇから」',
#   'GUMI_AMAE_10.0': '…………………………',
#   'GUMI_AMAE_1.0': '「お前、何か言うたんちゃうか？」「はいはい、お疲れ様でしたー」',
#   'GUMI_T_3': 'みんなが静かになるまでに先生の悪口言ってましたよ',
#   'Neural_Joking_Machine': '俺達の戦いはまだ始まったばかりなのに、俺が妻子かけてる間に、これからどうやって戦おうってもらう…。',
#   'llama': '仏像の石垣で石垣仏',
#   'GUMI_AE': '俺のムスコにソックリ！',
#   'GUMI_AMAE_1000.0': 'お前ら、絶対に押すなよっ。'},
#  {'image_number': 392633,
#   'human': 'どうにかして背中を見たい',
#   'star': 156,
#   'caption': '鏡の前に白い下着姿の男が横たわっている。',
#   'GUMI_AMAE_100.0': '「この子ったら、また変な花瓶を割ってしまいました。」',
#   'GUMI_AMAE_10.0': 'この顔に見える',
#   'GUMI_AMAE_1.0': '「あの人、昨日までここにあった魚が見当たらない…」',
#   'GUMI_T_3': '「はい、もしもし？もしもー？」「あ、うん…」',
#   'Neural_Joking_Machine': '「お前、何やってんだ？」',
#   'llama': 'こんにちは、お元気ですか？',
#   'GUMI_AE': 'お客様、こちらの方です',
#   'GUMI_AMAE_1000.0': '「この中に裏切り者がいる」と呼び寄せる'},
#  {'image_number': 640106,
#   'human': '「バス」『ロマン！』',
#   'star': 519,
#   'caption': '2人の男性がスーツを着て、お互いにハイファイブをあげ合っている',
#   'GUMI_AMAE_100.0': '「俺の財宝か？欲しけりゃくれてやる。探せ！この世のすべてをそこに置いてきた！」',
#   'GUMI_AMAE_10.0': '…………',
#   'GUMI_AMAE_1.0': '「お前、今俺の頭にメリージーボ入れたの」「うるせー！」',
#   'GUMI_T_3': '「この子は私の息子だ」と、しつこい。',
#   'Neural_Joking_Machine': '「この人、誰だったか思い出して」',
#   'llama': 'スーツを着て、お互いにハイファイブをあげ合っている画像に対して一言。',
#   'GUMI_AE': '「お前も痔だな」',
#   'GUMI_AMAE_1000.0': 'お父さん！！そんなに見つめないで！'},
#  {'image_number': 254794,
#   'human': 'お前さぁ〜、こんな見通しのいい場所で、しかもそんな目立つ色の服着て、俺を尾行できると思ってたん？',
#   'star': 326,
#   'caption': 'を見ながら浜辺に立つ二人の少年たち',
#   'GUMI_AMAE_100.0': '「お父さん、お母さん、お父さんやめてよ」と言ったら、この有様',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前の父ちゃん、昔ワルだったのに、、、」',
#   'GUMI_T_3': '「僕らがやってる？」『…うん、今から言う？』',
#   'Neural_Joking_Machine': 'お前の命はあと3000ボルトくらいかな',
#   'llama': '「あいつら、きっと友達だな。」',
#   'GUMI_AE': 'あ、ごめん、俺が悪かった。',
#   'GUMI_AMAE_1000.0': 'お前が来てから居場所が無い！'},
#  {'image_number': 593141,
#   'human': '１２時以降に餌を与えてしまった',
#   'star': 432,
#   'caption': '地面の雪に猫が横たわっている',
#   'GUMI_AMAE_100.0': '「あ、あの雲は私が守る」と言って、去勢された',
#   'GUMI_AMAE_10.0': '「・・・」',
#   'GUMI_AMAE_1.0': '「お前の席ねーから」',
#   'GUMI_T_3': '「お風呂は嫌い」と言った結果',
#   'Neural_Joking_Machine': '「おい、お茶をくれ。」「もういい！」',
#   'llama': 'ここは猫の天国。',
#   'GUMI_AE': 'お前は虎だ！虎になるのだ！',
#   'GUMI_AMAE_1000.0': 'この後スタッフが美味しくいただかれました。'},
#  {'image_number': 672837,
#   'human': 'この子がこれをするようになった経緯が知りたい。',
#   'star': 539,
#   'caption': 'ニンジンを食べるバニーの衣装を着た少女',
#   'GUMI_AMAE_100.0': '「お前の頭が磁石と同じってなー」「ああ。」',
#   'GUMI_AMAE_10.0': '何も無かった',
#   'GUMI_AMAE_1.0': 'この画像を見て、この画像を見た人は星をつけてください。',
#   'GUMI_T_3': '私、この人の家の子です',
#   'Neural_Joking_Machine': 'お前の母ちゃんで～べ～そ～',
#   'llama': 'ニンジンを食べるバニーの衣装を着た少女画像に対して一言。',
#   'GUMI_AE': '「俺、明日去勢なんだよなぁ…」「俺も、俺も知らんし。」',
#   'GUMI_AMAE_1000.0': '「お前ら、俺の事好き？」「お、俺が先に言えよ」'},
#  {'image_number': 473059,
#   'human': 'はい、お前は落としたやつ。',
#   'star': 170,
#   'caption': '草に腰かけている2人の少女',
#   'GUMI_AMAE_100.0': '「お前の頭の形が気になるから離せよ」',
#   'GUMI_AMAE_10.0': '「ねぇねぇ、この子、何で私の事見てるの？」',
#   'GUMI_AMAE_1.0': 'お前の頭、どんぐりみたいなら僕を作ってくれ',
#   'GUMI_T_3': 'これドロップちゃうおはじきや…',
#   'Neural_Joking_Machine': 'この後、スタッフが美味しく頂きました',
#   'llama': '草に腰かけている2人の少女画像に対して一言。',
#   'GUMI_AE': '「お父さん、僕がビッグに投げ飛ばされたの。」',
#   'GUMI_AMAE_1000.0': '「お前の母ちゃんデーベソ！」'},
#  {'image_number': 349866,
#   'human': '早送りっと・・・',
#   'star': 2869,
#   'caption': '男性が荷物を手渡すと、床にひざまずく女性',
#   'GUMI_AMAE_100.0': '「この子を見て、この中で何人もの男を見たんです」『はい、もしもし』',
#   'GUMI_AMAE_10.0': '「あ、目が覚めたわ。」',
#   'GUMI_AMAE_1.0': 'この子がチアリーダーに見える',
#   'GUMI_T_3': '「お年玉の代わりにこれをあげる」',
#   'Neural_Joking_Machine': '「はい、これ終えたら消しゴムよー」',
#   'llama': '「お代は結構です」',
#   'GUMI_AE': 'お前、俺が見えるのか？',
#   'GUMI_AMAE_1000.0': '「私は誰なのよ？」'},
#  {'image_number': 271978,
#   'human': '酸っぱ！',
#   'star': 657,
#   'caption': '地面でナッツを食べているリス',
#   'GUMI_AMAE_100.0': '「お前は今、猛烈に感動している」',
#   'GUMI_AMAE_10.0': 'この後、この後、少年が見えた',
#   'GUMI_AMAE_1.0': 'お前に食わせるタンメンはねぇ！',
#   'GUMI_T_3': 'あー！！あー！これ！これさえあればいいおっぱい出てきたー！！',
#   'Neural_Joking_Machine': '「お手」って言ったら、「バーン！」',
#   'llama': 'ナッツを食べているのではなく、ナッツを埋めているのだ。',
#   'GUMI_AE': 'あ、お前が見てる',
#   'GUMI_AMAE_1000.0': 'お前も、いずれこうなるぜ'},
#  {'image_number': 237875,
#   'human': '花束ありがとう、でもなんで俺が会社辞める流れになってるの？',
#   'star': 184,
#   'caption': '花束を持つ男性',
#   'GUMI_AMAE_100.0': '「私は外にさっと塗ったよ！」',
#   'GUMI_AMAE_10.0': '…………',
#   'GUMI_AMAE_1.0': '「この中に入ってる人は何人？」',
#   'GUMI_T_3': '「お手」と言われた',
#   'Neural_Joking_Machine': '「あ、ごめん。」',
#   'llama': '「やっと俺に気づいたか」',
#   'GUMI_AE': '「「「「「「おぎゃぉ！」」」」」」',
#   'GUMI_AMAE_1000.0': '「お前の席ねえからー!!」って言ってるけど、誰もいない…'},
#  {'image_number': 52866,
#   'human': 'ついに糖尿か・・',
#   'star': 168,
#   'caption': 'ウィニー プーさんのマスコットが通りを歩いている姿。',
#   'GUMI_AMAE_100.0': '「あ、ごめん、今日はカルカン？」',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お前、意外と足細いな」と言われた',
#   'GUMI_T_3': '「今日のパレードは、俺だけか」',
#   'Neural_Joking_Machine': 'この後、衝撃で、何が起こったか実験。',
#   'llama': '私がマスコットだと知ってるのは20人くらい。',
#   'GUMI_AE': 'この写真の中で一番の美人を見る方法を教えてください。',
#   'GUMI_AMAE_1000.0': '俺の頭の上を通り抜けようとして、封印されしの一撃をくらう。貴様の命など、救われない。'},
#  {'image_number': 412672,
#   'human': '起きた瞬間、遅刻を確信',
#   'star': 2685,
#   'caption': 'マスクの写真',
#   'GUMI_AMAE_100.0': 'お前が落とした斧は、この小麦粉みたいなチョコレートでできてるのよ！！',
#   'GUMI_AMAE_10.0': 'んな、な...',
#   'GUMI_AMAE_1.0': '「このボケすべりそうやわ～」',
#   'GUMI_T_3': 'ああ〜あ〜、明日月曜日じゃん……',
#   'Neural_Joking_Machine': '「お前の目が眩え…」',
#   'llama': 'マスクの写真画像に対して一言。',
#   'GUMI_AE': '俺の部屋に用心棒が！',
#   'GUMI_AMAE_1000.0': '俺は、明日、このサバイバルであいつを倒してやる！'},
#  {'image_number': 764490,
#   'human': '１０代後半と思われる女性が何らかの事件に巻き込まれた模様、遺体は何も身に着けてない！繰り返す！何も身に着けてない！',
#   'star': 9455,
#   'caption': '高速道路を走行するパトカー',
#   'GUMI_AMAE_100.0': '「この辺でドロンするんで」と言う度に、このポーズで誘惑に負けない',
#   'GUMI_AMAE_10.0': '',
#   'GUMI_AMAE_1.0': '「お父さん、お母さん！」「あら、お父さん！」',
#   'GUMI_T_3': 'この先の渋滞が渋滞',
#   'Neural_Joking_Machine': '「俺の車に当たってない！」',
#   'llama': '高速道路を走行するパトカー画像に対して一言。',
#   'GUMI_AE': 'この辺に落としたはず…',
#   'GUMI_AMAE_1000.0': '俺のボケが評価された'},
#  {'image_number': 181249,
#   'human': '黄身がいなくなってから殻に閉じこもってばかりだ',
#   'star': 110,
#   'caption': '流しに卵を握る人。',
#   'GUMI_AMAE_100.0': '「俺の事はいいから早く行け！」',
#   'GUMI_AMAE_10.0': '(……………………………………………………………………………',
#   'GUMI_AMAE_1.0': 'お前のボケ面白くね！',
#   'GUMI_T_3': '「これが父さんの仕事です…」',
#   'Neural_Joking_Machine': '「あ、これ？俺の内臓だよ」',
#   'llama': '流しに卵を握る人。卵かけご飯',
#   'GUMI_AE': '「あ～あ、お前が俺の飼い始めて「お前が鬼の顔を見て元気出せよ」って',
#   'GUMI_AMAE_1000.0': '「あ、あの…僕の顔、こんなんでいいですって！？」'}]

# %%
with open("generated_ohgiri.json", "w") as f:
    json.dump(datas, f)
