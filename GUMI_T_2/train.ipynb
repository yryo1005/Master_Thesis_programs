# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 128
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: 64
# - LEARNING RATE: 0.0001
# - FEATURE DIM: 1024
# - NUM_HEAD: 8

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 64 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 8
# Out:
# 25
# 2025-01-04 23:41:29.793388: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-04 23:41:29.940801: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-04 23:41:29.987542: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-04 23:41:30.307381: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-04 23:41:31.521773: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Cloning into 'Japanese_BPEEncoder_V2'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 43 (delta 24), reused 35 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 1.14 MiB | 6.31 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# result directory: ../../results/GUMI_T_2/False_False_False_0_32_4_31_25_64_0.0001_1024_8/
# 100%|█████████████████████████████████| 668970/668970 [06:44<00:00, 1654.99it/s]
# 100%|█████████████████████████████| 2135982/2135982 [00:03<00:00, 677641.23it/s]
# 100%|█████████████████████████████| 2051435/2051435 [00:02<00:00, 914349.85it/s]
# 学習に用いる大喜利の数: 2030920
#  検証に用いる大喜利の数: 20515
#  使用する画像の数: 244286
#  単語の種類: 16705
# 100%|███████████████████████████████| 244286/244286 [00:00<00:00, 342788.22it/s]
# 100%|█████████████████████████████| 2030920/2030920 [00:06<00:00, 328784.40it/s]
# num data: 2030920
# 100%|█████████████████████████████████| 20515/20515 [00:00<00:00, 696436.70it/s]
# num data: 20515
# Epoch 1/25: 100%|█| 31734/31734 [1:07:04<00:00,  7.88it/s, train_loss=4.53, trai
# Evaluating: 100%|█| 321/321 [00:33<00:00,  9.70it/s, test_loss=4.21, test_accura
# Epoch: 1/25, Train Loss: 4.5333, Train Accuracy: 0.2744, Test Loss: 4.2133, Test Accuracy: 0.2986
# -------------------------
# Epoch 2/25: 100%|█| 31734/31734 [1:00:45<00:00,  8.71it/s, train_loss=4.06, trai
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.97it/s, test_loss=4.08, test_accura
# Epoch: 2/25, Train Loss: 4.0575, Train Accuracy: 0.3097, Test Loss: 4.0676, Test Accuracy: 0.3134
# -------------------------
# Epoch 3/25: 100%|█| 31734/31734 [1:06:25<00:00,  7.96it/s, train_loss=3.89, trai
# Evaluating: 100%|█| 321/321 [00:39<00:00,  8.05it/s, test_loss=4, test_accuracy=
# Epoch: 3/25, Train Loss: 3.8948, Train Accuracy: 0.3232, Test Loss: 4.0034, Test Accuracy: 0.3198
# -------------------------
# Epoch 4/25: 100%|█| 31734/31734 [1:05:41<00:00,  8.05it/s, train_loss=3.79, trai
# Evaluating: 100%|█| 321/321 [00:30<00:00, 10.61it/s, test_loss=3.98, test_accura
# Epoch: 4/25, Train Loss: 3.7902, Train Accuracy: 0.3322, Test Loss: 3.9672, Test Accuracy: 0.3238
# -------------------------
# Epoch 5/25: 100%|█| 31734/31734 [1:10:44<00:00,  7.48it/s, train_loss=3.71, trai
# Evaluating: 100%|█| 321/321 [01:06<00:00,  4.84it/s, test_loss=3.95, test_accura
# Epoch: 5/25, Train Loss: 3.7122, Train Accuracy: 0.3391, Test Loss: 3.9481, Test Accuracy: 0.3269
# -------------------------
# Epoch 6/25: 100%|█| 31734/31734 [1:10:13<00:00,  7.53it/s, train_loss=3.65, trai
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.87it/s, test_loss=3.94, test_accura
# Epoch: 6/25, Train Loss: 3.6495, Train Accuracy: 0.3448, Test Loss: 3.9390, Test Accuracy: 0.3286
# -------------------------
# Epoch 7/25: 100%|█| 31734/31734 [1:19:30<00:00,  6.65it/s, train_loss=3.6, train
# Evaluating: 100%|█| 321/321 [00:30<00:00, 10.44it/s, test_loss=3.95, test_accura
# Epoch: 7/25, Train Loss: 3.5964, Train Accuracy: 0.3498, Test Loss: 3.9351, Test Accuracy: 0.3297
# -------------------------
# Epoch 8/25: 100%|█| 31734/31734 [1:04:57<00:00,  8.14it/s, train_loss=3.55, trai
# Evaluating: 100%|█| 321/321 [00:30<00:00, 10.60it/s, test_loss=3.93, test_accura
# Epoch: 8/25, Train Loss: 3.5501, Train Accuracy: 0.3542, Test Loss: 3.9341, Test Accuracy: 0.3298
# -------------------------
# Epoch 9/25: 100%|█| 31734/31734 [1:08:14<00:00,  7.75it/s, train_loss=3.51, trai
# Evaluating: 100%|█| 321/321 [00:30<00:00, 10.63it/s, test_loss=3.94, test_accura
# Epoch: 9/25, Train Loss: 3.5087, Train Accuracy: 0.3583, Test Loss: 3.9368, Test Accuracy: 0.3309
# -------------------------
# Epoch 10/25: 100%|█| 31734/31734 [1:04:06<00:00,  8.25it/s, train_loss=3.47, tra
# Evaluating: 100%|█| 321/321 [00:30<00:00, 10.62it/s, test_loss=3.94, test_accura
# Epoch: 10/25, Train Loss: 3.4709, Train Accuracy: 0.3622, Test Loss: 3.9438, Test Accuracy: 0.3307
# -------------------------
# Epoch 11/25: 100%|█| 31734/31734 [1:03:27<00:00,  8.33it/s, train_loss=3.44, tra
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.81it/s, test_loss=3.95, test_accura
# Epoch: 11/25, Train Loss: 3.4362, Train Accuracy: 0.3657, Test Loss: 3.9515, Test Accuracy: 0.3305
# -------------------------
# Epoch 12/25: 100%|█| 31734/31734 [1:05:09<00:00,  8.12it/s, train_loss=3.4, trai
# Evaluating: 100%|█| 321/321 [00:30<00:00, 10.61it/s, test_loss=3.97, test_accura
# Epoch: 12/25, Train Loss: 3.4038, Train Accuracy: 0.3691, Test Loss: 3.9608, Test Accuracy: 0.3303
# -------------------------
# Epoch 13/25: 100%|█| 31734/31734 [1:09:16<00:00,  7.63it/s, train_loss=3.37, tra
# Evaluating: 100%|█| 321/321 [00:30<00:00, 10.57it/s, test_loss=3.97, test_accura
# Epoch: 13/25, Train Loss: 3.3735, Train Accuracy: 0.3723, Test Loss: 3.9701, Test Accuracy: 0.3301
# -------------------------
# Epoch 14/25: 100%|█| 31734/31734 [1:05:49<00:00,  8.03it/s, train_loss=3.34, tra
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.92it/s, test_loss=3.98, test_accura
# Epoch: 14/25, Train Loss: 3.3449, Train Accuracy: 0.3755, Test Loss: 3.9836, Test Accuracy: 0.3296
# -------------------------
# Epoch 15/25: 100%|█| 31734/31734 [1:09:08<00:00,  7.65it/s, train_loss=3.32, tra
# Evaluating: 100%|█| 321/321 [00:31<00:00, 10.06it/s, test_loss=3.99, test_accura
# Epoch: 15/25, Train Loss: 3.3181, Train Accuracy: 0.3785, Test Loss: 3.9916, Test Accuracy: 0.3291
# -------------------------
# Epoch 16/25: 100%|█| 31734/31734 [1:08:19<00:00,  7.74it/s, train_loss=3.29, tra
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.89it/s, test_loss=4.02, test_accura
# Epoch: 16/25, Train Loss: 3.2926, Train Accuracy: 0.3814, Test Loss: 4.0034, Test Accuracy: 0.3287
# -------------------------
# Epoch 17/25: 100%|█| 31734/31734 [1:05:59<00:00,  8.01it/s, train_loss=3.27, tra
# Evaluating: 100%|█| 321/321 [00:30<00:00, 10.52it/s, test_loss=4.03, test_accura
# Epoch: 17/25, Train Loss: 3.2686, Train Accuracy: 0.3842, Test Loss: 4.0163, Test Accuracy: 0.3281
# -------------------------
# Epoch 18/25: 100%|█| 31734/31734 [1:04:27<00:00,  8.21it/s, train_loss=3.25, tra
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.85it/s, test_loss=4.03, test_accura
# Epoch: 18/25, Train Loss: 3.2459, Train Accuracy: 0.3867, Test Loss: 4.0258, Test Accuracy: 0.3276
# -------------------------
# Epoch 19/25: 100%|█| 31734/31734 [1:06:50<00:00,  7.91it/s, train_loss=3.22, tra
# Evaluating: 100%|█| 321/321 [00:30<00:00, 10.44it/s, test_loss=4.04, test_accura
# Epoch: 19/25, Train Loss: 3.2244, Train Accuracy: 0.3893, Test Loss: 4.0365, Test Accuracy: 0.3274
# -------------------------
# Epoch 20/25: 100%|█| 31734/31734 [1:09:19<00:00,  7.63it/s, train_loss=3.2, trai
# Evaluating: 100%|█| 321/321 [00:30<00:00, 10.53it/s, test_loss=4.05, test_accura
# Epoch: 20/25, Train Loss: 3.2041, Train Accuracy: 0.3917, Test Loss: 4.0471, Test Accuracy: 0.3268
# -------------------------
# Epoch 21/25: 100%|█| 31734/31734 [1:05:28<00:00,  8.08it/s, train_loss=3.18, tra
# Evaluating: 100%|█| 321/321 [01:06<00:00,  4.82it/s, test_loss=4.06, test_accura
# Epoch: 21/25, Train Loss: 3.1847, Train Accuracy: 0.3941, Test Loss: 4.0618, Test Accuracy: 0.3262
# -------------------------
# Epoch 22/25: 100%|█| 31734/31734 [1:05:24<00:00,  8.09it/s, train_loss=3.17, tra
# Evaluating: 100%|█| 321/321 [00:32<00:00,  9.89it/s, test_loss=4.07, test_accura
# Epoch: 22/25, Train Loss: 3.1663, Train Accuracy: 0.3963, Test Loss: 4.0735, Test Accuracy: 0.3249
# -------------------------
# Epoch 23/25: 100%|█| 31734/31734 [1:10:13<00:00,  7.53it/s, train_loss=3.15, tra
# Evaluating: 100%|█| 321/321 [00:30<00:00, 10.55it/s, test_loss=4.09, test_accura
# Epoch: 23/25, Train Loss: 3.1489, Train Accuracy: 0.3985, Test Loss: 4.0818, Test Accuracy: 0.3249
# -------------------------
# Epoch 24/25: 100%|█| 31734/31734 [1:06:04<00:00,  8.00it/s, train_loss=3.13, tra
# Evaluating: 100%|█| 321/321 [00:30<00:00, 10.57it/s, test_loss=4.09, test_accura
# Epoch: 24/25, Train Loss: 3.1323, Train Accuracy: 0.4006, Test Loss: 4.0940, Test Accuracy: 0.3242
# -------------------------
# Epoch 25/25: 100%|█| 31734/31734 [1:05:43<00:00,  8.05it/s, train_loss=3.12, tra
# Evaluating: 100%|█| 321/321 [01:01<00:00,  5.21it/s, test_loss=4.1, test_accurac
# Epoch: 25/25, Train Loss: 3.1164, Train Accuracy: 0.4025, Test Loss: 4.1035, Test Accuracy: 0.3242
# -------------------------

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: 32
# - LEARNING RATE: 0.0001
# - FEATURE DIM: 1024
# - NUM_HEAD: 8

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 32 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 8
# Out:
# 25
# 2025-01-06 04:02:59.433784: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-06 04:02:59.537391: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-06 04:02:59.570792: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-06 04:02:59.811000: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-06 04:03:00.948765: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# result directory: ../../results/GUMI_T_2/False_False_False_0_32_4_31_25_32_0.0001_1024_8/
# 100%|█████████████████████████████████| 668970/668970 [04:50<00:00, 2304.77it/s]
# 100%|█████████████████████████████| 2135982/2135982 [00:03<00:00, 682726.20it/s]
# 100%|█████████████████████████████| 2051435/2051435 [00:02<00:00, 953117.76it/s]
# 学習に用いる大喜利の数: 2030920
#  検証に用いる大喜利の数: 20515
#  使用する画像の数: 244286
#  単語の種類: 16705
# 100%|███████████████████████████████| 244286/244286 [00:00<00:00, 360168.46it/s]
# 100%|█████████████████████████████| 2030920/2030920 [00:06<00:00, 328809.57it/s]
# num data: 2030920
# 100%|█████████████████████████████████| 20515/20515 [00:00<00:00, 754446.63it/s]
# num data: 20515
# Epoch 1/25: 100%|█| 63467/63467 [1:12:20<00:00, 14.62it/s, train_loss=4.5, train
# Evaluating: 100%|█| 642/642 [00:33<00:00, 19.39it/s, test_loss=4.21, test_accura
# Epoch: 1/25, Train Loss: 4.5013, Train Accuracy: 0.2760, Test Loss: 4.2063, Test Accuracy: 0.2972
# -------------------------
# Epoch 2/25: 100%|█| 63467/63467 [1:15:08<00:00, 14.08it/s, train_loss=4.06, trai
# Evaluating: 100%|█| 642/642 [01:04<00:00,  9.97it/s, test_loss=4.07, test_accura
# Epoch: 2/25, Train Loss: 4.0613, Train Accuracy: 0.3097, Test Loss: 4.0719, Test Accuracy: 0.3116
# -------------------------
# Epoch 3/25: 100%|█| 63467/63467 [1:15:57<00:00, 13.93it/s, train_loss=3.91, trai
# Evaluating: 100%|█| 642/642 [01:04<00:00,  9.97it/s, test_loss=4.01, test_accura
# Epoch: 3/25, Train Loss: 3.9131, Train Accuracy: 0.3224, Test Loss: 4.0113, Test Accuracy: 0.3191
# -------------------------
# Epoch 4/25: 100%|█| 63467/63467 [1:18:14<00:00, 13.52it/s, train_loss=3.82, trai
# Evaluating: 100%|█| 642/642 [01:04<00:00,  9.94it/s, test_loss=3.99, test_accura
# Epoch: 4/25, Train Loss: 3.8200, Train Accuracy: 0.3308, Test Loss: 3.9766, Test Accuracy: 0.3230
# -------------------------
# Epoch 5/25: 100%|█| 63467/63467 [1:18:52<00:00, 13.41it/s, train_loss=3.75, trai
# Evaluating: 100%|█| 642/642 [01:04<00:00,  9.92it/s, test_loss=3.97, test_accura
# Epoch: 5/25, Train Loss: 3.7512, Train Accuracy: 0.3370, Test Loss: 3.9535, Test Accuracy: 0.3254
# -------------------------
# Epoch 6/25: 100%|█| 63467/63467 [1:18:06<00:00, 13.54it/s, train_loss=3.7, train
# Evaluating: 100%|█| 642/642 [00:56<00:00, 11.29it/s, test_loss=3.94, test_accura
# Epoch: 6/25, Train Loss: 3.6966, Train Accuracy: 0.3420, Test Loss: 3.9365, Test Accuracy: 0.3274
# -------------------------
# Epoch 7/25: 100%|█| 63467/63467 [1:15:07<00:00, 14.08it/s, train_loss=3.65, trai
# Evaluating: 100%|█| 642/642 [00:33<00:00, 19.45it/s, test_loss=3.93, test_accura
# Epoch: 7/25, Train Loss: 3.6507, Train Accuracy: 0.3463, Test Loss: 3.9262, Test Accuracy: 0.3291
# -------------------------
# Epoch 8/25: 100%|█| 63467/63467 [1:16:30<00:00, 13.82it/s, train_loss=3.61, trai
# Evaluating: 100%|█| 642/642 [00:37<00:00, 17.03it/s, test_loss=3.92, test_accura
# Epoch: 8/25, Train Loss: 3.6111, Train Accuracy: 0.3501, Test Loss: 3.9195, Test Accuracy: 0.3301
# -------------------------
# Epoch 9/25: 100%|█| 63467/63467 [1:16:29<00:00, 13.83it/s, train_loss=3.58, trai
# Evaluating: 100%|█| 642/642 [01:04<00:00,  9.92it/s, test_loss=3.93, test_accura
# Epoch: 9/25, Train Loss: 3.5762, Train Accuracy: 0.3534, Test Loss: 3.9136, Test Accuracy: 0.3308
# -------------------------
# Epoch 10/25: 100%|█| 63467/63467 [1:13:27<00:00, 14.40it/s, train_loss=3.54, tra
# Evaluating: 100%|█| 642/642 [00:33<00:00, 19.19it/s, test_loss=3.92, test_accura
# Epoch: 10/25, Train Loss: 3.5443, Train Accuracy: 0.3565, Test Loss: 3.9106, Test Accuracy: 0.3316
# -------------------------
# Epoch 11/25: 100%|█| 63467/63467 [1:13:16<00:00, 14.44it/s, train_loss=3.52, tra
# Evaluating: 100%|█| 642/642 [01:00<00:00, 10.55it/s, test_loss=3.92, test_accura
# Epoch: 11/25, Train Loss: 3.5152, Train Accuracy: 0.3594, Test Loss: 3.9102, Test Accuracy: 0.3320
# -------------------------
# Epoch 12/25: 100%|█| 63467/63467 [1:11:09<00:00, 14.86it/s, train_loss=3.49, tra
# Evaluating: 100%|█| 642/642 [00:32<00:00, 19.52it/s, test_loss=3.92, test_accura
# Epoch: 12/25, Train Loss: 3.4881, Train Accuracy: 0.3620, Test Loss: 3.9113, Test Accuracy: 0.3319
# -------------------------
# Epoch 13/25: 100%|█| 63467/63467 [1:15:30<00:00, 14.01it/s, train_loss=3.46, tra
# Evaluating: 100%|█| 642/642 [00:33<00:00, 19.41it/s, test_loss=3.91, test_accura
# Epoch: 13/25, Train Loss: 3.4632, Train Accuracy: 0.3645, Test Loss: 3.9072, Test Accuracy: 0.3324
# -------------------------
# Epoch 14/25: 100%|█| 63467/63467 [1:14:10<00:00, 14.26it/s, train_loss=3.44, tra
# Evaluating: 100%|█| 642/642 [00:33<00:00, 19.45it/s, test_loss=3.93, test_accura
# Epoch: 14/25, Train Loss: 3.4398, Train Accuracy: 0.3669, Test Loss: 3.9141, Test Accuracy: 0.3322
# -------------------------
# Epoch 15/25:  32%|▎| 20019/63467 [28:45<1:19:27,  9.11it/s, train_loss=3.42, tra

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **128**
# - LEARNING RATE: 0.0001
# - FEATURE DIM: 1024
# - NUM_HEAD: 8

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 128 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 8

# %% [markdown]
# # OLD

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: 512
# - LEARNING RATE: 0.001
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 512 \
    --learning_rate 0.001 \
    --feature_dim 1024 \
    --num_heads 4
# Out:
# 22

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **1024**
# - LEARNING RATE: 0.001
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 1024 \
    --learning_rate 0.001 \
    --feature_dim 1024 \
    --num_heads 4

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **256**
# - LEARNING RATE: 0.001
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 256 \
    --learning_rate 0.001 \
    --feature_dim 1024 \
    --num_heads 4

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: 512
# - LEARNING RATE: **0.0001**
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 512 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 4

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **128**
# - LEARNING RATE: **0.0001**
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 128 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 4
# Out:
# 22
# 2025-01-01 16:05:15.435582: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-01 16:05:15.588423: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-01 16:05:15.630806: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-01 16:05:15.933524: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-01 16:05:17.033499: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# result directory: ../../results/GUMI_T/False_False_False_0_32_4_31_25_128_0.0001_1024_4/
#  39%|████████████▊                    | 260451/668970 [02:36<04:06, 1654.64it/s]
