# %% [markdown]
# # Cross Attentionが1層

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **256**
# - LEARNING RATE: 0.0001
# - FEATURE DIM: 1024
# - NUM_HEAD: 8

# %%
import os

num_workers = int(os.cpu_count() * 0.7)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 256 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 8
# Out:
# 19
# 2025-01-07 07:45:43.922093: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-07 07:45:44.068823: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-07 07:45:44.109324: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-07 07:45:44.420826: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-07 07:45:45.778520: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# result directory: ../../results/GUMI_T_2/False_False_False_0_32_4_31_25_256_0.0001_1024_8/
# 学習に用いる大喜利の数: 2030920
#  検証に用いる大喜利の数: 20515
#  使用する画像の数: 244286
#  単語の種類: 16705
# 100%|███████████████████████████████| 244286/244286 [00:00<00:00, 818961.87it/s]
# 100%|█████████████████████████████| 2030920/2030920 [00:03<00:00, 603182.54it/s]
# num data: 2030920
# 100%|████████████████████████████████| 20515/20515 [00:00<00:00, 1286632.87it/s]
# num data: 20515
# /home/user/workspace/Master_Thesis/Master_Thesis_programs/GUMI_T_2/train.py:525: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"{RESULT_DIR}model_{len(train_loss_history):03}.pth"))
# Epoch 7/25: 100%|█| 7934/7934 [1:15:06<00:00,  1.76it/s, train_loss=3.63, train_
# Evaluating: 100%|█| 81/81 [00:49<00:00,  1.63it/s, test_loss=3.95, test_accuracy
# Epoch: 7/25, Train Loss: 3.6271, Train Accuracy: 0.3464, Test Loss: 3.9519, Test Accuracy: 0.3275
# -------------------------
# Epoch 8/25: 100%|█| 7934/7934 [1:13:35<00:00,  1.80it/s, train_loss=3.57, train_
# Evaluating: 100%|█| 81/81 [00:48<00:00,  1.67it/s, test_loss=3.95, test_accuracy
# Epoch: 8/25, Train Loss: 3.5723, Train Accuracy: 0.3514, Test Loss: 3.9533, Test Accuracy: 0.3283
# -------------------------
# Epoch 9/25: 100%|█| 7934/7934 [1:13:52<00:00,  1.79it/s, train_loss=3.53, train_
# Evaluating: 100%|█| 81/81 [00:50<00:00,  1.61it/s, test_loss=3.96, test_accuracy
# Epoch: 9/25, Train Loss: 3.5253, Train Accuracy: 0.3558, Test Loss: 3.9563, Test Accuracy: 0.3293
# -------------------------
# Epoch 10/25: 100%|█| 7934/7934 [1:13:57<00:00,  1.79it/s, train_loss=3.48, train
# Evaluating: 100%|█| 81/81 [00:48<00:00,  1.66it/s, test_loss=3.96, test_accuracy
# Epoch: 10/25, Train Loss: 3.4831, Train Accuracy: 0.3600, Test Loss: 3.9613, Test Accuracy: 0.3296
# -------------------------
# Epoch 11/25: 100%|█| 7934/7934 [1:13:26<00:00,  1.80it/s, train_loss=3.44, train
# Evaluating: 100%|█| 81/81 [00:49<00:00,  1.62it/s, test_loss=3.97, test_accuracy
# Epoch: 11/25, Train Loss: 3.4449, Train Accuracy: 0.3638, Test Loss: 3.9727, Test Accuracy: 0.3295
# -------------------------
# Epoch 12/25: 100%|█| 7934/7934 [1:13:23<00:00,  1.80it/s, train_loss=3.41, train
# Evaluating: 100%|█| 81/81 [00:48<00:00,  1.67it/s, test_loss=3.99, test_accuracy
# Epoch: 12/25, Train Loss: 3.4098, Train Accuracy: 0.3674, Test Loss: 3.9872, Test Accuracy: 0.3297
# -------------------------
# Epoch 13/25: 100%|█| 7934/7934 [1:12:36<00:00,  1.82it/s, train_loss=3.38, train
# Evaluating: 100%|█| 81/81 [00:48<00:00,  1.66it/s, test_loss=4.01, test_accuracy
# Epoch: 13/25, Train Loss: 3.3772, Train Accuracy: 0.3708, Test Loss: 4.0058, Test Accuracy: 0.3289
# -------------------------
# Epoch 14/25: 100%|█| 7934/7934 [1:12:59<00:00,  1.81it/s, train_loss=3.35, train
# Evaluating: 100%|█| 81/81 [00:48<00:00,  1.66it/s, test_loss=4.02, test_accuracy
# Epoch: 14/25, Train Loss: 3.3468, Train Accuracy: 0.3741, Test Loss: 4.0204, Test Accuracy: 0.3281
# -------------------------
# Epoch 15/25: 100%|█| 7934/7934 [1:13:42<00:00,  1.79it/s, train_loss=3.32, train
# Evaluating: 100%|█| 81/81 [00:48<00:00,  1.66it/s, test_loss=4.03, test_accuracy
# Epoch: 15/25, Train Loss: 3.3184, Train Accuracy: 0.3773, Test Loss: 4.0343, Test Accuracy: 0.3274
# -------------------------
# Epoch 16/25: 100%|█| 7934/7934 [1:12:59<00:00,  1.81it/s, train_loss=3.29, train
# Evaluating: 100%|█| 81/81 [00:51<00:00,  1.58it/s, test_loss=4.05, test_accuracy
# Epoch: 16/25, Train Loss: 3.2920, Train Accuracy: 0.3803, Test Loss: 4.0481, Test Accuracy: 0.3269
# -------------------------
# Epoch 17/25: 100%|█| 7934/7934 [1:13:40<00:00,  1.79it/s, train_loss=3.27, train
# Evaluating: 100%|█| 81/81 [00:48<00:00,  1.67it/s, test_loss=4.06, test_accuracy
# Epoch: 17/25, Train Loss: 3.2673, Train Accuracy: 0.3831, Test Loss: 4.0632, Test Accuracy: 0.3259
# -------------------------
# Epoch 18/25: 100%|█| 7934/7934 [1:13:41<00:00,  1.79it/s, train_loss=3.24, train
# Evaluating: 100%|█| 81/81 [00:48<00:00,  1.66it/s, test_loss=4.08, test_accuracy
# Epoch: 18/25, Train Loss: 3.2438, Train Accuracy: 0.3858, Test Loss: 4.0795, Test Accuracy: 0.3263
# -------------------------
# Epoch 19/25: 100%|█| 7934/7934 [1:13:42<00:00,  1.79it/s, train_loss=3.22, train
# Evaluating: 100%|█| 81/81 [00:51<00:00,  1.57it/s, test_loss=4.09, test_accuracy
# Epoch: 19/25, Train Loss: 3.2214, Train Accuracy: 0.3885, Test Loss: 4.0945, Test Accuracy: 0.3248
# -------------------------
# Epoch 20/25: 100%|█| 7934/7934 [1:13:54<00:00,  1.79it/s, train_loss=3.2, train_
# Evaluating: 100%|█| 81/81 [00:48<00:00,  1.66it/s, test_loss=4.11, test_accuracy
# Epoch: 20/25, Train Loss: 3.2004, Train Accuracy: 0.3910, Test Loss: 4.1077, Test Accuracy: 0.3240
# -------------------------
# Epoch 21/25: 100%|█| 7934/7934 [1:13:15<00:00,  1.81it/s, train_loss=3.18, train
# Evaluating: 100%|█| 81/81 [00:48<00:00,  1.66it/s, test_loss=4.12, test_accuracy
# Epoch: 21/25, Train Loss: 3.1802, Train Accuracy: 0.3934, Test Loss: 4.1228, Test Accuracy: 0.3236
# -------------------------
# Epoch 22/25: 100%|█| 7934/7934 [1:13:25<00:00,  1.80it/s, train_loss=3.16, train
# Evaluating: 100%|█| 81/81 [00:47<00:00,  1.72it/s, test_loss=4.14, test_accuracy
# Epoch: 22/25, Train Loss: 3.1612, Train Accuracy: 0.3958, Test Loss: 4.1361, Test Accuracy: 0.3221
# -------------------------
# Epoch 23/25: 100%|█| 7934/7934 [1:13:11<00:00,  1.81it/s, train_loss=3.14, train
# Evaluating: 100%|█| 81/81 [00:51<00:00,  1.56it/s, test_loss=4.15, test_accuracy
# Epoch: 23/25, Train Loss: 3.1432, Train Accuracy: 0.3980, Test Loss: 4.1461, Test Accuracy: 0.3219
# -------------------------
# Epoch 24/25: 100%|█| 7934/7934 [1:13:39<00:00,  1.80it/s, train_loss=3.13, train
# Evaluating: 100%|█| 81/81 [00:47<00:00,  1.72it/s, test_loss=4.15, test_accuracy
# Epoch: 24/25, Train Loss: 3.1257, Train Accuracy: 0.4002, Test Loss: 4.1546, Test Accuracy: 0.3220
# -------------------------
# Epoch 25/25: 100%|█| 7934/7934 [1:13:27<00:00,  1.80it/s, train_loss=3.11, train
# Evaluating: 100%|█| 81/81 [00:47<00:00,  1.71it/s, test_loss=4.17, test_accuracy
# Epoch: 25/25, Train Loss: 3.1088, Train Accuracy: 0.4023, Test Loss: 4.1662, Test Accuracy: 0.3217
# -------------------------

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **32**
# - LEARNING RATE: 0.0001
# - FEATURE DIM: 1024
# - NUM_HEAD: 8

# %%
import os

num_workers = int(os.cpu_count() * 0.7)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 32 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 8
# Out:
# 19
# 2025-01-08 07:22:28.922309: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-08 07:22:29.016212: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-08 07:22:29.043813: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-08 07:22:29.248985: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-08 07:22:30.307022: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# result directory: ../../results/GUMI_T_2/False_False_False_0_32_4_31_25_32_0.0001_1024_8/
# 100%|█████████████████████████████████| 668970/668970 [07:04<00:00, 1574.54it/s]
# 100%|█████████████████████████████| 2135982/2135982 [00:02<00:00, 746475.50it/s]
# 100%|████████████████████████████| 2051435/2051435 [00:02<00:00, 1016582.97it/s]
# 学習に用いる大喜利の数: 2030920
#  検証に用いる大喜利の数: 20515
#  使用する画像の数: 244286
#  単語の種類: 16705
# 100%|███████████████████████████████| 244286/244286 [00:00<00:00, 328741.21it/s]
# 100%|█████████████████████████████| 2030920/2030920 [00:06<00:00, 321707.74it/s]
# num data: 2030920
# 100%|█████████████████████████████████| 20515/20515 [00:00<00:00, 717721.09it/s]
# num data: 20515
# Epoch 1/25: 100%|█| 63467/63467 [1:10:20<00:00, 15.04it/s, train_loss=4.5, train
# Evaluating: 100%|█| 642/642 [00:45<00:00, 14.13it/s, test_loss=4.22, test_accura
# Epoch: 1/25, Train Loss: 4.5040, Train Accuracy: 0.2764, Test Loss: 4.2154, Test Accuracy: 0.2985
# -------------------------
# Epoch 2/25: 100%|█| 63467/63467 [1:11:27<00:00, 14.80it/s, train_loss=4.06, trai/25:  58%|▌| 36568/63467 [40:38<30:32, 14.68it/s, train_loss=4.1, train_a
# Evaluating: 100%|█| 642/642 [00:48<00:00, 13.17it/s, test_loss=4.09, test_accura
# Epoch: 2/25, Train Loss: 4.0648, Train Accuracy: 0.3098, Test Loss: 4.0807, Test Accuracy: 0.3119
# -------------------------
# Epoch 3/25: 100%|█| 63467/63467 [1:11:40<00:00, 14.76it/s, train_loss=3.92, trai/25:  66%|▋| 41937/63467 [47:54<19:00, 18.87it/s, train_loss=3.94, train_
# Evaluating: 100%|█| 642/642 [00:45<00:00, 13.96it/s, test_loss=4.03, test_accura
# Epoch: 3/25, Train Loss: 3.9193, Train Accuracy: 0.3221, Test Loss: 4.0220, Test Accuracy: 0.3189
# -------------------------
# Epoch 4/25: 100%|█| 63467/63467 [1:10:17<00:00, 15.05it/s, train_loss=3.83, trai
# Evaluating: 100%|█| 642/642 [00:46<00:00, 13.90it/s, test_loss=4, test_accuracy=
# Epoch: 4/25, Train Loss: 3.8283, Train Accuracy: 0.3301, Test Loss: 3.9827, Test Accuracy: 0.3230
# -------------------------
# Epoch 5/25: 100%|█| 63467/63467 [1:10:45<00:00, 14.95it/s, train_loss=3.76, trai/25:  44%|▍| 28027/63467 [31:14<32:15, 18.31it/s, train_loss=3.78, train_
# Evaluating: 100%|█| 642/642 [00:50<00:00, 12.68it/s, test_loss=3.99, test_accura
# Epoch: 5/25, Train Loss: 3.7614, Train Accuracy: 0.3361, Test Loss: 3.9613, Test Accuracy: 0.3256
# -------------------------
# Epoch 6/25: 100%|█| 63467/63467 [1:10:36<00:00, 14.98it/s, train_loss=3.71, trai
# Evaluating: 100%|█| 642/642 [00:46<00:00, 13.86it/s, test_loss=3.96, test_accura
# Epoch: 6/25, Train Loss: 3.7078, Train Accuracy: 0.3411, Test Loss: 3.9430, Test Accuracy: 0.3278
# -------------------------
# Epoch 7/25:  25%|▏| 15630/63467 [17:21<49:55, 15.97it/s, train_loss=3.68, train_

# %% [markdown]
# # 2025/1/6

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 128
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: 64
# - LEARNING RATE: 0.0001
# - FEATURE DIM: 1024
# - NUM_HEAD: 8

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 64 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 8

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **128**
# - LEARNING RATE: 0.0001
# - FEATURE DIM: 1024
# - NUM_HEAD: 8

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 128 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 8
# Out:
# 19
# 2025-01-05 07:16:13.357684: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-05 07:16:14.135145: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-05 07:16:14.361412: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-05 07:16:15.978589: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-05 07:16:22.630982: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# result directory: ../../results/GUMI_T_2/False_False_False_0_32_4_31_25_128_0.0001_1024_8/
# 学習に用いる大喜利の数: 2030920
#  検証に用いる大喜利の数: 20515
#  使用する画像の数: 244286
#  単語の種類: 16705
# 100%|████████████████████████████████| 244286/244286 [00:12<00:00, 19897.51it/s]
# 100%|█████████████████████████████| 2030920/2030920 [00:05<00:00, 360573.27it/s]
# num data: 2030920
# 100%|█████████████████████████████████| 20515/20515 [00:00<00:00, 745969.99it/s]
# num data: 20515
# /home/user/workspace/Master_Thesis/Master_Thesis_programs/GUMI_T_2/train.py:525: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"{RESULT_DIR}model_{len(train_loss_history):03}.pth"))
# Epoch 2/25:   4%| | 691/15867 [15:02<11:40:27,  2.77s/it, train_loss=4.24, train

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: 512
# - LEARNING RATE: 0.001
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 512 \
    --learning_rate 0.001 \
    --feature_dim 1024 \
    --num_heads 4
# Out:
# 22

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **1024**
# - LEARNING RATE: 0.001
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 1024 \
    --learning_rate 0.001 \
    --feature_dim 1024 \
    --num_heads 4

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **256**
# - LEARNING RATE: 0.001
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 256 \
    --learning_rate 0.001 \
    --feature_dim 1024 \
    --num_heads 4

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: 512
# - LEARNING RATE: **0.0001**
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 512 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 4

# %% [markdown]
# - イラスト画像を学習に用いない
# - 文字が含まれる画像を学習に用いない
# - 固有名詞を含む大喜利を学習に用いない
# - 大喜利の最小の星の数: 0
# - 単語の最小出現回数: 32
# - 大喜利の最小単語数: 4
# - 大喜利の最大単語数: 31
# - EPOCH: 25
# - BATCH SIZE: **128**
# - LEARNING RATE: **0.0001**
# - FEATURE DIM: 1024
# - NUM_HEAD: 4

# %%
import os

num_workers = int(os.cpu_count() * 0.8)
print(num_workers)

# !python train.py \
    --num_workers {num_workers} \
    --min_star 0 \
    --min_apper_word 32 \
    --min_sentence_length 4\
    --max_sentence_length 31 \
    --epoch 25 \
    --batch_size 128 \
    --learning_rate 0.0001 \
    --feature_dim 1024 \
    --num_heads 4
# Out:
# 22
# 2025-01-01 16:05:15.435582: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-01 16:05:15.588423: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-01 16:05:15.630806: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-01 16:05:15.933524: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-01 16:05:17.033499: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# result directory: ../../results/GUMI_T/False_False_False_0_32_4_31_25_128_0.0001_1024_4/
#  39%|████████████▊                    | 260451/668970 [02:36<04:06, 1654.64it/s]
